# %% [markdown]
# #DSen2 Superresolution
# *Johannes Mast and Matjaž Krebs in collaboration with Žiga Kokalj*
#
#
# *14.07.2020*

# %% [markdown]
# ## Introduction
#
#
# This script is an implementation of *Super-resolution of Sentinel-2 images: Learning a globally applicable deep neural network* [[Link]](https://arxiv.org/abs/1803.04271) by Charis Lanaras, José Bioucas-Dias, Silvano Galliani, Emmanuel Baltsavias and Konrad Schindler. The code for preprocessing, the model, and the model weights were made available online on [github](https://github.com/lanha/DSen2) and credit for developing and testing the model and the preprocessing goes to them.
#
# Johannes Mast, the [author of this script](https://github.com/JohMast), adapted the code under supervision of Žiga Kokalj for operational use and Matjaž Krebs adapted it further for his diploma thesis to train the weights specifically for the territory of Slovenia in order to test the viability of the supperesolved datasets for drought detection. In doing so we removed certain functionalities removed, specifically query options, and thereby simplified the code. Further, changes allow the functions to be applied to a list of files.
#
# The published code is suitable to be called via command line. The functions were adapted so they can be used as python functions within a script such as the present one.

# %% [markdown]
# ## Overview
#
# For a demonstration of the inner workings of the DSen2 code, we refer to the [demonstration script](https://github.com/JohMast/DSen2_Implementation/blob/master/Demonstration_of_DSen2_Superresolution_.ipynb) which can be executed in google colab on a VM with the only requirements being a Google Drive with about 2GB available space, and an account on the [Copernicus Open Access Hub](https://scihub.copernicus.eu/dhus/).
#
# In the present script, we will merely see how to use the high-level functions which, as mentioned previously, are simplified but faster. Unlike the demonstration script, this script is tied to the contents of the [github repository](https://github.com/JohMast/DSen2_Implementation) and relies on the files available there. It is intended to be run on google colab but should also work just fine on other platforms that have the required Python 3 packages. Notably, as of the time that this script was created, Tensorflow 1 is required.

# %% [markdown]
# ## The Script

# %% [markdown]
# This script consists of three parts:
#
# *   First, we will do a quick **Setup**. This is necessary on google colab and the steps may vary on other platforms. Afterwards, we have access to two alternatives:
# *   **A: Training**: This consists of preprocessing of the training data and the training of the model itself, either from scratch or from a previously created weights file.
# *   **B: Prediction**: This is the superresolution. We predict on our images using a previously created weights file.
#
# Since weights files are provided for all network types, it is not necessary to perform **A** before **B**. However, it might make sense to tune the network to our images before the prediction.

# %% [markdown]
# ### Setup

# %% [markdown]
# ####Directory Structure
# For the purpose of this script, we will assume that the following file structure already exists:
#
# * DSen2OP
#     * Data
#         * Inputs
#             * `Input Sentinel-2 Files, zipped`
#         * Outputs
#         * Training
#     * DSen2
#         * models
#             * `The model weights`
#         * python
#             * `All python files`
#
# However, this is only a suggestion. You can adjust the path names in the script to your own directory structure. Only the structure within the DSen2 folder should be kept intact.

# %% [markdown]
# #### Connecting to Google Drive
#
# Every time the notebook runtime is started, it must be reconnected to the Google Drive.
# Therefore, this must be done at the beginning of every script. An authorisation code is required as an input by the user.

# %%
# %%capture
from google.colab import drive
from importlib import reload

drive.mount('/content/gdrive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········

# %% [markdown]
# #### Navigating to the folder
#
# We usually have a main working directory from which we operate. For us, it is called `DSen2OP`. We navigate to it.

# %%
#prvotno v zvezku
# %cd "gdrive/My Drive/DSen2OP"
# Out:
# /content/gdrive/My Drive/DSen2OP

# %% [markdown]
# #### Selecting  Tensorflow Version
#
# Colab VMs offer different versions of tensorflow - here, we need tensorflow 1.15.0, the default as of 27.03.2020 is tensorflow 2.

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
# Out:
# TensorFlow 1.x selected.
# Tensorflow version 1.15.2

# %% [markdown]
# ### Pridobivanje podatkov

# %%
####prenos posnetkov
#programski paketi
# %%capture
# !pip install rasterio
# !pip install geopandas
# !pip install descartes
# !pip install gdal
# !pip install sentinelsat
# !pip install geojson
# !pip install shapely
# !pip install Pillow

# %%
n_dl_images=30

# %%
#območje
lon_min=13.5
lon_max=16
lat_min= 45.5
lat_max= 46.5

# %%
# povezava na api
from sentinelsat.sentinel import SentinelAPI, read_geojson, geojson_to_wkt
from datetime import date
import getpass
# connect to the API
api = SentinelAPI(getpass.getpass(prompt="Please enter Copernicus Open Access Hub username"),
                  getpass.getpass(prompt="Please enter Copernicus Open Access Hub password"),
                  'https://scihub.copernicus.eu/dhus')
# Out:
# Please enter Copernicus Open Access Hub username··········
# Please enter Copernicus Open Access Hub password··········

# %%
#poligon AOI

aoi = 'POLYGON((%s %s,%s %s,%s %s,%s %s,%s %s))'  %(lon_min,lat_min,lon_min,lat_max,lon_max,lat_max,lon_max,lat_min,lon_min,lat_min)
import plotly.graph_objects as go
fig = go.Figure(go.Scattermapbox(
    fill = "toself",text="Query Area",
    lon = [lon_min, lon_max, lon_max, lon_min],
    lat = [lat_max, lat_max, lat_min, lat_min],
    marker = { 'size': 10, 'color': "red" }))
fig.update_layout(
     title="AOI for the Query",font=dict(family="Arial",size=18,),
     mapbox = {
        'style': "stamen-terrain",
        'center': {'lon': ((lon_min+lon_max)/2), 'lat': ((lat_min+lat_max)/2) },
        'zoom': 4},
    showlegend = False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bd9bfca1-4aa8-43c2-b32e-f5d5601433ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bd9bfca1-4aa8-43c2-b32e-f5d5601433ef")) {
#                     Plotly.newPlot(
#                         'bd9bfca1-4aa8-43c2-b32e-f5d5601433ef',
#                         [{"fill": "toself", "lat": [46.5, 46.5, 45.5, 45.5], "lon": [13.5, 16, 16, 13.5], "marker": {"color": "red", "size": 10}, "text": "Query Area", "type": "scattermapbox"}],
#                         {"font": {"family": "Arial", "size": 18}, "mapbox": {"center": {"lat": 46.0, "lon": 14.75}, "style": "stamen-terrain", "zoom": 4}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}],  ...

# %%
#query
# search by polygon, time, and SciHub query keywords
products = api.query(aoi,
                     date=('20190301', date(2019, 5, 31)),
                     platformname='Sentinel-2',
                     cloudcoverpercentage=(0, 10))

# %%
# convert to Pandas DataFrame
products_df = api.to_dataframe(products)

# sort and limit to first n_dl_images sorted products
products_df_sorted = products_df.sort_values(['cloudcoverpercentage', 'ingestiondate',], ascending=[True, True])
products_df_sorted = products_df_sorted.head(n_dl_images)
products_df_sorted
# Out:
#                                                                                   title  ...                                datastripidentifier
# 900db3ef-ff9b-4f0a-b0e5-07f5eea720f8  S2A_MSIL1C_20190302T100021_N0207_R122_T33TUL_2...  ...  S2A_OPER_MSI_L1C_DS_SGS__20190302T134355_S2019...
# 74499ca0-f454-4af3-bbea-4d4714f3e52b  S2A_MSIL1C_20190312T100021_N0207_R122_T33TUL_2...  ...  S2A_OPER_MSI_L1C_DS_MPS__20190312T120945_S2019...
# c742f36f-835a-4d00-b9f4-e76aa32a4654  S2A_MSIL1C_20190421T100031_N0207_R122_T33TWM_2...  ...  S2A_OPER_MSI_L1C_DS_MPS__20190421T121337_S2019...
# 187576f0-3e8f-41a6-bc61-67383cd891ac  S2B_MSIL1C_20190416T100029_N0207_R122_T33TUL_2...  ...  S2B_OPER_MSI_L1C_DS_EPAE_20190416T125918_S2019...
# c4299f25-86ba-493f-adb4-f3f3a18dd116  S2B_MSIL1C_20190419T101029_N0207_R022_T33TVL_2...  ...  S2B_OPER_MSI_L1C_DS_MPS__20190419T122357_S2019...
# 2b41e2fb-6cbb-4701-aca9-72f86a587b94  S2A_MSIL2A_20190312T100021_N0211_R122_T33TUL_2...  ...                                                NaN
# 7c1e5df2-28ca-43ba-a4f7-270cca41b279  S2A_MSIL1C_20190312T100021_N0207_R122_T33TVM_2...  ...  S2A_OPER_MSI_L1C_DS_SGS__20190312T134427_S2019...
# e36fcfa9-a273-4323-9128-e478436836c3  S2A_MSIL1C_20190322T100031_N0207_R122_T33TWM_2...  ...  S2A_OPER_MSI_L1C_DS_MPS__20190322T121010_S2019...
# 93e2fe28-31d2-4f83-b601-e14abd848e4a  S2A_MSIL1C_20190421T100031_N0207_R122_T33TVM_2...  ...  S2A_OPER_MSI_L1C_DS_MPS__20190421T121337_S2019...
# f33566e0-ce21-442c-a1cc-f13f211d7704  S2A_MSIL2A_20190302T100021_N0211_R122_T33TUL_2...  ...                                                NaN
# 191fc39d-7ecb-4ff4-ad4e-679ec1ae4e06  S2B_MSIL1C_20190416T100029_N0207_R122_T33TVL_2...  ...  S2B_OPER_MSI_L1C_DS_EPAE_20190416T125918_S2019...
# 00d9c93b-7a3d-47e2-be7d-d473bdfaf363  S2B_MSIL1C_20190416T100029_N0207_R122_T33TWM_2...  ...  S2B_OPER_MSI_L1C_DS_EPAE_20190416T125918_S2019...
# ae5424be-a4b7-4842-9a14-9813ecc1280c  S2A_MSIL1C_20190501T100031_N0207_R122_T33TUL_2...  ...  S2A_OPER_MSI_L1C_DS_EPAE_20190501T110719_S2019...
# 0fd59a57-7b05-4747-a197-e0809a09d457  S2A_MSIL2A_20190421T100031_N0211_R122_T33TWM_2...  ...                                                NaN
#
# [30 rows x 42 columns]

# %%
#izpis v excel
import pandas as pd
df = products_df_sorted

writer = pd.ExcelWriter('2018.xlsx', mode= 'a')
df.to_excel(writer, sheet_name='sep-dec30')
writer.save()

# %%
# download sorted and reduced products
#%%capture 

api.download_all(products_df_sorted.index,"Data/novo/")
# Out:
# Downloading:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Downloading:   1%|          | 7.34M/1.17G [00:02<10:30, 1.85MB/s]
# Downloading:   0%|          | 1.05M/1.08G [00:01<22:44, 794kB/s]
# Downloading:   1%|          | 9.44M/1.17G [00:02<08:29, 2.28MB/s]
# Downloading:   1%|          | 12.6M/1.17G [00:02<06:27, 2.99MB/s]
# Downloading:   1%|▏         | 14.7M/1.17G [00:03<05:11, 3.72MB/s]
# Downloading:   2%|▏         | 17.8M/1.17G [00:03<04:07, 4.67MB/s]
# Downloading:   2%|▏         | 19.9M/1.17G [00:03<03:34, 5.37MB/s]
# Downloading:   2%|▏         | 23.1M/1.17G [00:03<03:00, 6.37MB/s]
# Downloading:   2%|▏         | 26.2M/1.17G [00:04<02:37, 7.29MB/s]
# Downloading:   3%|▎         | 31.5M/1.17G [00:04<01:55, 9.85MB/s]
# Downloading:   2%|▏         | 25.2M/1.08G [00:03<02:27, 7.19MB/s]
# Downloading:   3%|▎         | 33.6M/1.17G [00:04<02:08, 8.83MB/s]
# Downloading:   3%|▎         | 35.7M/1.17G [00:05<02:48, 6.75MB/s]
# Downloading:   3%|▎         | 34.6M/1.08G [00:04<01:48, 9.65MB/s]
# Downloading:   3%|▎         | 37.7M/1.08G [00:04<01:42, 10.2MB/s]
# Downloading:   3%|▎         | 37.7M/1.17G [00:05<03:31, 5.36MB/s]
# Downloading:   3%|▎         | 38.8M/1.17G [00:06<03:52, 4.87MB/s]
# Downloading:   4%|▎         | 41.9M/1.17G [00:06<03:14, 5.83MB/s]
# Downloading:   4%|▍         | 45.1M/1.17G [00:06<02:48, 6.70MB/s]
# Downloading:   5%|▍         | 52.4M/1.08G [00:06<01:30, 11.4MB/s]
# Downloading:   4%|▍         | 48.2M/1.17G [00:07<03:01, 6.19MB/s]
# Downloading:   5%|▌         | 58.7M/1.08G [00:06<01:28, 11.6MB/s]
# Downloading:   4%|▍         | 51.4M/1.17G [00:08<03:08, 5.94MB/s]
# Downloading:   6%|▌         | 65.0M/1.08G [00:07<01:27, 11.7MB/s]
# Downloading:   6%|▋         | 68.2M/1.08G [00:07<01:26, 11.7MB/s]
# Downloading:   5%|▍         | 53.5M/1.17G [00:08<03:45, 4.95MB/s]
# Downloading:   5%|▍         | 56.6M/1.17G [00:08<03:07, 5.95MB/s]
# Downloading:   5%|▍         | 57.7M/1.17G [00:09<03:38, 5.10MB/s]
# Downloading:   5%|▌         | 59.8M/1.17G [00:09<03:19, 5.58MB/s]
# Downloading:   5%|▌         | 60.8M/1.17G [00:09<03:36, 5.13MB/s]
# Downloading:   5%|▌         | 62.9M/1.17G [00:10<03:22, 5.49MB/s]
# Downloading:   6%|▌         | 65.0M/1.17G [00:10<03:08, 5.88MB/s]
# Downloading:   6%|▌         | 66.1M/1.17G [00:10<03:30, 5.25MB/s]
# Downloading:   6%|▌         | 68.2M/1.17G [00:10<03:12, 5.74MB/s]
# Downloading:   6%|▌         | 69.2M/1.17G [00:11<03:18, 5.56MB/s]
# Downloading:   6%|▌         | 71.3M/1.17G [00:11<03:10, 5.77MB/s]
# Downloading:   6%|▋         | 73.4M/1.17G [00:11<02:57, 6.21MB/s]
# Downloading:  10%|▉         | 107M/1.08G [00:10<01:35, 10.2MB/s]
# Downloading:   6%|▋         | 75.5M/1.17G [00:11<02:51, 6.38MB/s]
# Downloading:   7%|▋         | 76.5M/1.17G [00:12<03:12, 5.70MB/s]
# Downloading:   7%|▋         | 78.6M/1.17G [00:12<02:59, 6.11MB/s]
# Downloading:   7%|▋         | 80.7M/1.17G [00:12<02:54, 6.26MB/s]
# Downloading:   7%|▋         | 82.8M/1.17G [00:13<02:47, 6.51MB/s]
# Downloading:   7%|▋         | 83.9M/1.17G [00:13<03:04, 5.90MB/s]
# Downloading:   7%|▋         | 86.0M/1.17G [00:13<03:00, 6.02MB/s]
# Downloading:   8%|▊         | 88.1M/1.17G [00:13<02:52, 6.29MB/s]
# Downloading:   8%|▊         | 90.2M/1.17G [00:14<02:49, 6.39MB/s]
# Downloading:   8%|▊         | 91.2M/1.17G [00:14<03:02, 5.94MB/s]
# Downloading:   8%|▊         | 93.3M/1.17G [00:14<02:53, 6.21MB/s]
# Downloading:  13%|█▎        | 143M/1.08G [00:13<01:20, 11.7MB/s]
# Downloading:   8%|▊         | 96.5M/1.17G [00:15<02:37, 6.83MB/s]
# Downloading:   8%|▊         | 98.6M/1.17G [00:15<02:39, 6.74MB/s]
# Downloading:   8%|▊         | 99.6M/1.17G [00:15<02:50, 6.29MB/s]
# Downloading:   9%|▊         | 102M/1.17G [00:16<02:44, 6.52MB/s]
# Downloading:   9%|▉         | 104M/1.17G [00:16<02:46, 6.41MB/s]
# Downloading:   9%|▉         | 105M/1.17G [00:16<02:56, 6.06MB/s]
# Downloading:   9%|▉         | 107M/1.17G [00:16<02:44, 6.49MB/s]
# Downloading:   9%|▉         | 108M/1.17G [00:17<03:07, 5.69MB/s]
# Downloading:   9%|▉         | 109M/1.17G [00:17<02:51, 6.22MB/s]
# Downloading:   9%|▉         | 111M/1.17G [00:17<02:58, 5.94MB/s]
# Downloading:  10%|▉         | 112M/1.17G [00:17<03:04, 5.74MB/s]
# Downloading:  10%|▉         | 114M/1.17G [00:18<02:59, 5.90MB/s]
# Downloading:  10%|▉         | 116M/1.17G [00:18<02:40, 6.58MB/s]
# Downloading:  10%|█         | 117M/1.17G [00:18<02:56, 5.97MB/s]
# Downloading:  10%|█         | 120M/1.17G [00:19<02:49, 6.20MB/s]
# Downloading:  10%|█         | 121M/1.17G [00:19<02:35, 6.76MB/s]
# Downloading:  10%|█         | 123M/1.17G [00:19<02:47, 6.28MB/s]
# Downloading:  11%|█         | 124M/1.17G [00:19<02:44, 6.38MB/s]
# Downloading:  11%|█         | 126M/1.17G [00:19<02:39, 6.58MB/s]
# Downloading:  11%|█         | 128M/1.17G [00:20<02:33, 6.79MB/s]
# Downloading:  11%|█         | 129M/1.17G [00:20<02:49, 6.16MB/s]
# Downloading:  11%|█         | 131M/1.17G [00:20<02:46, 6.25MB/s]
# Downloading:  11%|█▏        | 133M/1.17G [00:21<02:43, 6.36MB/s]
# Downloading:  12%|█▏        | 135M/1.17G [00:21<02:35, 6.65MB/s]
# Downloading:  12%|█▏        | 136M/1.17G [00:21<02:42, 6.39MB/s]
# Downloading:  12%|█▏        | 138M/1.17G [00:21<02:40, 6.44MB/s]
# Downloading:  21%|██        | 228M/1.08G [00:21<01:12, 11.8MB/s]
# Downloading:  12%|█▏        | 141M/1.17G [00:22<02:40, 6.44MB/s]
# Downloading:  12%|█▏        | 143M/1.17G [00:22<02:37, 6.55MB/s]
# Downloading:  12%|█▏        | 145M/1.17G [00:22<02:43, 6.29MB/s]
# Downloading:  13%|█▎        | 147M/1.17G [00:23<02:40, 6.38MB/s]
# Downloading:  13%|█▎        | 149M/1.17G [00:23<02:36, 6.55MB/s]
# Downloading:  13%|█▎        | 150M/1.17G [00:23<02:51, 5.98MB/s]
# Downloading:  13%|█▎        | 152M/1.17G [00:24<02:46, 6.13MB/s]
# Downloading:  23%|██▎       | 253M/1.08G [00:23<01:10, 11.8MB/s]
# Downloading:  13%|█▎        | 154M/1.17G [00:24<02:42, 6.25MB/s]
# Downloading:  13%|█▎        | 155M/1.17G [00:24<04:13, 4.01MB/s]
# Downloading:  24%|██▍       | 262M/1.08G [00:24<01:09, 11.8MB/s]
# Downloading:  14%|█▎        | 159M/1.17G [00:25<03:15, 5.19MB/s]
# Downloading:  25%|██▍       | 268M/1.08G [00:24<01:09, 11.8MB/s]
# Downloading:  14%|█▎        | 160M/1.17G [00:25<03:48, 4.44MB/s]
# Downloading:  14%|█▍        | 161M/1.17G [00:26<04:15, 3.96MB/s]
# Downloading:  14%|█▍        | 163M/1.17G [00:26<04:32, 3.71MB/s]
# Downloading:  14%|█▍        | 164M/1.17G [00:26<04:40, 3.60MB/s]
# Downloading:  14%|█▍        | 165M/1.17G [00:27<04:37, 3.63MB/s]
# Downloading:  27%|██▋       | 287M/1.08G [00:26<01:07, 11.8MB/s]
# Downloading:  14%|█▍        | 166M/1.17G [00:27<04:50, 3.47MB/s]
# Downloading:  14%|█▍        | 167M/1.17G [00:27<04:56, 3.39MB/s]
# Downloading:  14%|█▍        | 168M/1.17G [00:27<04:50, 3.46MB/s]
# Downloading:  14%|█▍        | 169M/1.17G [00:28<04:51, 3.44MB/s]
# Downloading:  14%|█▍        | 170M/1.17G [00:28<04:50, 3.46MB/s]
# Downloading:  15%|█▍        | 171M/1.17G [00:28<04:50, 3.45MB/s]
# Downloading:  15%|█▍        | 172M/1.17G [00:29<04:33, 3.65MB/s]
# Downloading:  15%|█▍        | 173M/1.17G [00:29<04:33, 3.66MB/s]
# Downloading:  15%|█▍        | 174M/1.17G [00:29<04:41, 3.55MB/s]
# Downloading:  15%|█▍        | 175M/1.17G [00:30<04:36, 3.61MB/s]
# Downloading:  30%|██▉       | 322M/1.08G [00:29<01:04, 11.8MB/s]
# Downloading:  15%|█▌        | 176M/1.17G [00:30<04:38, 3.58MB/s]
# Downloading:  15%|█▌        | 177M/1.17G [00:30<04:34, 3.63MB/s]
# Downloading:  15%|█▌        | 178M/1.17G [00:30<04:24, 3.76MB/s]
# Downloading:  15%|█▌        | 179M/1.17G [00:31<04:31, 3.66MB/s]
# Downloading:  15%|█▌        | 180M/1.17G [00:31<04:32, 3.64MB/s]
# Downloading:  15%|█▌        | 181M/1.17G [00:31<04:29, 3.68MB/s]
# Downloading:  16%|█▌        | 182M/1.17G [00:32<04:29, 3.67MB/s]
# Downloading:  16%|█▌        | 184M/1.17G [00:32<04:27, 3.69MB/s]
# Downloading:  16%|█▌        | 185M/1.17G [00:32<04:28, 3.67MB/s]
# Downloading:  16%|█▌        | 186M/1.17G [00:32<04:39, 3.54MB/s]
# Downloading:  16%|█▌        | 187M/1.17G [00:33<04:38, 3.54MB/s]
# Downloading:  16%|█▌        | 188M/1.17G [00:33<04:35, 3.57MB/s]
# Downloading:  33%|███▎      | 363M/1.08G [00:32<01:01, 11.8MB/s]
# Downloading:  16%|█▌        | 189M/1.17G [00:33<04:36, 3.56MB/s]
# Downloading:  16%|█▌        | 190M/1.17G [00:34<04:42, 3.48MB/s]
# Downloading:  16%|█▋        | 191M/1.17G [00:34<04:24, 3.71MB/s]
# Downloading:  16%|█▋        | 192M/1.17G [00:34<04:27, 3.66MB/s]
# Downloading:  16%|█▋        | 193M/1.17G [00:34<04:27, 3.66MB/s]
# Downloading:  17%|█▋        | 194M/1.17G [00:35<04:27, 3.65MB/s]
# Downloading:  17%|█▋        | 195M/1.17G [00:35<04:27, 3.66MB/s]
# Downloading:  17%|█▋        | 196M/1.17G [00:35<04:32, 3.59MB/s]
# Downloading:  36%|███▌      | 391M/1.08G [00:34<00:58, 11.8MB/s]
# Downloading:  17%|█▋        | 198M/1.17G [00:36<04:23, 3.70MB/s]
# Downloading:  37%|███▋      | 397M/1.08G [00:35<00:58, 11.8MB/s]
# Downloading:  17%|█▋        | 199M/1.17G [00:36<04:53, 3.32MB/s]
# Downloading:  17%|█▋        | 200M/1.17G [00:37<05:06, 3.17MB/s]
# Downloading:  38%|███▊      | 407M/1.08G [00:36<00:57, 11.8MB/s]
# Downloading:  17%|█▋        | 201M/1.17G [00:37<05:09, 3.13MB/s]
# Downloading:  17%|█▋        | 202M/1.17G [00:37<05:12, 3.11MB/s]
# Downloading:  17%|█▋        | 203M/1.17G [00:38<05:10, 3.12MB/s]
# Downloading:  39%|███▊      | 417M/1.08G [00:37<01:00, 11.0MB/s]
# Downloading:  17%|█▋        | 204M/1.17G [00:38<05:08, 3.14MB/s]
# Downloading:  18%|█▊        | 206M/1.17G [00:38<05:04, 3.18MB/s]
# Downloading:  39%|███▉      | 424M/1.08G [00:37<01:01, 10.8MB/s]
# Downloading:  18%|█▊        | 207M/1.17G [00:39<04:58, 3.23MB/s]
# Downloading:  18%|█▊        | 208M/1.17G [00:39<04:57, 3.24MB/s]
# Downloading:  40%|███▉      | 429M/1.08G [00:38<01:14, 8.76MB/s]
# Downloading:  18%|█▊        | 209M/1.17G [00:39<04:48, 3.34MB/s]
# Downloading:  40%|███▉      | 432M/1.08G [00:38<01:10, 9.20MB/s]
# Downloading:  40%|███▉      | 433M/1.08G [00:38<01:15, 8.63MB/s]
# Downloading:  18%|█▊        | 210M/1.17G [00:40<04:47, 3.35MB/s]
# Downloading:  40%|████      | 436M/1.08G [00:39<01:05, 9.84MB/s]
# Downloading:  18%|█▊        | 211M/1.17G [00:40<04:43, 3.39MB/s]
# Downloading:  41%|████      | 439M/1.08G [00:39<01:00, 10.6MB/s]
# Downloading:  18%|█▊        | 212M/1.17G [00:40<04:43, 3.39MB/s]
# Downloading:  18%|█▊        | 213M/1.17G [00:40<04:41, 3.40MB/s]
# Downloading:  41%|████      | 446M/1.08G [00:40<00:55, 11.5MB/s]
# Downloading:  18%|█▊        | 214M/1.17G [00:41<04:31, 3.53MB/s]
# Downloading:  18%|█▊        | 215M/1.17G [00:41<04:30, 3.54MB/s]
# Downloading:  18%|█▊        | 216M/1.17G [00:41<04:31, 3.52MB/s]
# Downloading:  19%|█▊        | 217M/1.17G [00:42<04:23, 3.62MB/s]
# Downloading:  19%|█▊        | 218M/1.17G [00:42<04:26, 3.59MB/s]
# Downloading:  19%|█▊        | 219M/1.17G [00:42<04:26, 3.58MB/s]
# Downloading:  19%|█▉        | 220M/1.17G [00:42<04:20, 3.66MB/s]
# Downloading:  19%|█▉        | 221M/1.17G [00:43<04:23, 3.60MB/s]
# Downloading:  19%|█▉        | 222M/1.17G [00:43<04:18, 3.67MB/s]
# Downloading:  44%|████▎     | 474M/1.08G [00:42<00:52, 11.6MB/s]
# Downloading:  19%|█▉        | 223M/1.17G [00:43<04:18, 3.66MB/s]
# Downloading:  19%|█▉        | 224M/1.17G [00:44<04:16, 3.70MB/s]
# Downloading:  19%|█▉        | 225M/1.17G [00:44<04:17, 3.68MB/s]
# Downloading:  19%|█▉        | 226M/1.17G [00:44<04:14, 3.71MB/s]
# Downloading:  19%|█▉        | 228M/1.17G [00:44<04:16, 3.68MB/s]
# Downloading:  19%|█▉        | 229M/1.17G [00:45<04:14, 3.71MB/s]
# Downloading:  20%|█▉        | 230M/1.17G [00:45<04:17, 3.66MB/s]
# Downloading:  20%|█▉        | 231M/1.17G [00:45<04:18, 3.64MB/s]
# Downloading:  20%|█▉        | 232M/1.17G [00:46<04:06, 3.81MB/s]
# Downloading:  20%|█▉        | 233M/1.17G [00:46<03:58, 3.95MB/s]
# Downloading:  20%|█▉        | 234M/1.17G [00:46<04:08, 3.78MB/s]
# Downloading:  20%|██        | 235M/1.17G [00:46<04:28, 3.49MB/s]
# Downloading:  20%|██        | 236M/1.17G [00:47<04:11, 3.72MB/s]
# Downloading:  20%|██        | 237M/1.17G [00:47<04:20, 3.59MB/s]
# Downloading:  48%|████▊     | 521M/1.08G [00:46<00:47, 11.8MB/s]
# Downloading:  20%|██        | 238M/1.17G [00:47<04:26, 3.50MB/s]
# Downloading:  20%|██        | 239M/1.17G [00:48<04:31, 3.44MB/s]
# Downloading:  49%|████▊     | 527M/1.08G [00:47<00:51, 10.8MB/s]
# Downloading:  20%|██        | 240M/1.17G [00:48<04:39, 3.33MB/s]
# Downloading:  21%|██        | 241M/1.17G [00:48<04:38, 3.34MB/s]
# Downloading:  21%|██        | 242M/1.17G [00:49<04:21, 3.56MB/s]
# Downloading:  50%|████▉     | 537M/1.08G [00:48<00:47, 11.5MB/s]
# Downloading:  21%|██        | 243M/1.17G [00:49<04:18, 3.59MB/s]
# Downloading:  21%|██        | 244M/1.17G [00:49<04:14, 3.64MB/s]
# Downloading:  21%|██        | 245M/1.17G [00:49<04:10, 3.71MB/s]
# Downloading:  50%|█████     | 545M/1.08G [00:48<00:51, 10.4MB/s]
# Downloading:  21%|██        | 246M/1.17G [00:50<04:09, 3.72MB/s]
# Downloading:  21%|██        | 247M/1.17G [00:50<04:02, 3.82MB/s]
# Downloading:  38%|███▊      | 445M/1.17G [01:33<02:06, 5.74MB/s]
# Downloading:  38%|███▊      | 446M/1.17G [01:33<02:22, 5.09MB/s]
# Downloading:  38%|███▊      | 447M/1.17G [01:34<02:24, 5.02MB/s]
# Downloading:  38%|███▊      | 448M/1.17G [01:34<03:22, 3.58MB/s]
# Downloading:  38%|███▊      | 449M/1.17G [01:34<03:20, 3.62MB/s]
# Downloading:  38%|███▊      | 451M/1.17G [01:35<02:43, 4.41MB/s]
# Downloading:  39%|███▊      | 452M/1.17G [01:35<02:36, 4.60MB/s]
# Downloading:  39%|███▊      | 453M/1.17G [01:35<02:35, 4.62MB/s]
# Downloading:  39%|███▊      | 454M/1.17G [01:35<02:39, 4.51MB/s]
# Downloading:  97%|█████████▋| 1.05G/1.08G [01:35<00:02, 12.0MB/s]
# Downloading:  39%|███▉      | 455M/1.17G [01:36<02:44, 4.35MB/s]
# Downloading:  39%|███▉      | 456M/1.17G [01:36<02:43, 4.39MB/s]
# Downloading:  39%|███▉      | 458M/1.17G [01:36<02:20, 5.07MB/s]
# Downloading:  39%|███▉      | 459M/1.17G [01:36<02:25, 4.89MB/s]
# Downloading:  39%|███▉      | 460M/1.17G [01:37<02:29, 4.77MB/s]
# Downloading:  39%|███▉      | 461M/1.17G [01:37<02:26, 4.85MB/s]
# Downloading:  39%|███▉      | 462M/1.17G [01:37<02:10, 5.45MB/s]
# Downloading:  40%|███▉      | 463M/1.17G [01:37<02:15, 5.24MB/s]
# Downloading:  40%|███▉      | 466M/1.17G [01:38<01:58, 5.99MB/s]
# Downloading:  99%|█████████▉| 1.07G/1.08G [01:37<00:01, 8.09MB/s]
# Downloading:  40%|███▉      | 467M/1.17G [01:38<02:04, 5.66MB/s]
# Downloading:  40%|███▉      | 468M/1.17G [01:38<02:11, 5.35MB/s]
# Downloading:  40%|████      | 470M/1.17G [01:38<01:56, 6.05MB/s]
# Downloading: 100%|█████████▉| 1.08G/1.08G [01:37<00:00, 8.99MB/s]
# Downloading:  40%|████      | 471M/1.17G [01:39<02:04, 5.63MB/s]
# Downloading:  40%|████      | 472M/1.17G [01:39<02:12, 5.28MB/s]
# Downloading: 100%|██████████| 1.08G/1.08G [01:38<00:00, 11.0MB/s]
#
# Downloading:  40%|████      | 474M/1.17G [01:39<02:25, 4.80MB/s]
# Downloading:  41%|████      | 476M/1.17G [01:39<01:52, 6.19MB/s]
# MD5 checksumming:   4%|▍         | 44.4M/1.08G [00:00<8:24:53, 34.3kB/s]
# Downloading:  41%|████      | 477M/1.17G [01:40<01:57, 5.93MB/s]
# MD5 checksumming:  12%|█▏        | 133M/1.08G [00:00<3:46:20, 70.0kB/s]
# Downloading:  41%|████      | 478M/1.17G [01:40<02:04, 5.58MB/s]
# Downloading:  41%|████      | 479M/1.17G [01:40<01:50, 6.26MB/s]
# MD5 checksumming:  25%|██▍       | 268M/1.08G [00:00<1:06:35, 204kB/s]
# Downloading:  41%|████      | 480M/1.17G [01:40<01:52, 6.15MB/s]
# MD5 checksumming:  33%|███▎      | 360M/1.08G [00:01<28:59, 416kB/s]
# Downloading:  53%|█████▎    | 621M/1.17G [02:00<01:15, 7.28MB/s]
# Downloading:  53%|█████▎    | 624M/1.17G [02:00<01:06, 8.26MB/s]
# Downloading:  53%|█████▎    | 625M/1.17G [02:01<01:08, 8.02MB/s]
# Downloading:  53%|█████▎    | 626M/1.17G [02:01<01:03, 8.60MB/s]
# Downloading:  54%|█████▎    | 630M/1.17G [02:01<01:00, 8.91MB/s]
# Downloading:  54%|█████▍    | 633M/1.17G [02:01<00:55, 9.65MB/s]
# Downloading:  54%|█████▍    | 634M/1.17G [02:01<00:56, 9.53MB/s]
# Downloading:  54%|█████▍    | 635M/1.17G [02:02<00:56, 9.54MB/s]
# Downloading:  54%|█████▍    | 639M/1.17G [02:02<01:01, 8.75MB/s]
# Downloading:  55%|█████▍    | 641M/1.17G [02:02<00:55, 9.62MB/s]
# Downloading:  55%|█████▍    | 642M/1.17G [02:02<00:58, 9.06MB/s]
# Downloading:  18%|█▊        | 178M/975M [00:17<01:19, 9.98MB/s]
# Downloading:  55%|█████▍    | 644M/1.17G [02:03<01:02, 8.52MB/s]
# Downloading:  55%|█████▌    | 645M/1.17G [02:03<01:35, 5.52MB/s]
# Downloading:  55%|█████▌    | 647M/1.17G [02:03<01:29, 5.89MB/s]
# Downloading:  19%|█▉        | 187M/975M [00:18<01:20, 9.73MB/s]
# Downloading:  55%|█████▌    | 649M/1.17G [02:04<01:50, 4.73MB/s]
# Downloading:  19%|█▉        | 190M/975M [00:19<02:04, 6.32MB/s]
# Downloading:  56%|█████▌    | 652M/1.17G [02:04<01:34, 5.50MB/s]
# Downloading:  56%|█████▌    | 654M/1.17G [02:05<02:32, 3.40MB/s]
# Downloading:  56%|█████▌    | 657M/1.17G [02:05<01:59, 4.32MB/s]
# Downloading:  21%|██        | 203M/975M [00:20<01:30, 8.56MB/s]
# Downloading:  56%|█████▋    | 661M/1.17G [02:06<01:49, 4.66MB/s]
# Downloading:  57%|█████▋    | 664M/1.17G [02:06<01:42, 4.97MB/s]
# Downloading:  22%|██▏       | 211M/975M [00:21<01:44, 7.32MB/s]
# Downloading:  57%|█████▋    | 667M/1.17G [02:07<01:22, 6.16MB/s]
# Downloading:  57%|█████▋    | 668M/1.17G [02:07<01:26, 5.86MB/s]
# Downloading:  57%|█████▋    | 670M/1.17G [02:07<01:23, 6.02MB/s]
# Downloading:  57%|█████▋    | 671M/1.17G [02:07<01:20, 6.20MB/s]
# Downloading:  57%|█████▋    | 672M/1.17G [02:08<01:30, 5.53MB/s]
# Downloading:  58%|█████▊    | 675M/1.17G [02:08<01:16, 6.53MB/s]
# Downloading:  58%|█████▊    | 676M/1.17G [02:08<01:20, 6.20MB/s]
# Downloading:  23%|██▎       | 228M/975M [00:23<02:23, 5.20MB/s]
# Downloading:  58%|█████▊    | 678M/1.17G [02:09<01:14, 6.61MB/s]
# Downloading:  24%|██▎       | 231M/975M [00:24<01:45, 7.03MB/s]
# Downloading:  58%|█████▊    | 679M/1.17G [02:09<01:28, 5.55MB/s]
# Downloading:  90%|█████████ | 1.06G/1.17G [02:56<00:16, 6.83MB/s]
# Downloading:  72%|███████▏  | 701M/975M [01:11<00:27, 9.80MB/s]
# Downloading:  91%|█████████ | 1.06G/1.17G [02:56<00:14, 7.82MB/s]
# Downloading:  91%|█████████ | 1.07G/1.17G [02:57<00:12, 8.73MB/s]
# Downloading:  73%|███████▎  | 708M/975M [01:12<00:24, 10.8MB/s]
# Downloading:  91%|█████████ | 1.07G/1.17G [02:57<00:12, 8.36MB/s]
# Downloading:  91%|█████████ | 1.07G/1.17G [02:57<00:12, 8.29MB/s]
# Downloading:  92%|█████████▏| 1.07G/1.17G [02:58<00:11, 8.81MB/s]
# Downloading:  92%|█████████▏| 1.08G/1.17G [02:58<00:09, 10.0MB/s]
# Downloading:  92%|█████████▏| 1.08G/1.17G [02:58<00:08, 10.6MB/s]
# Downloading:  92%|█████████▏| 1.08G/1.17G [02:58<00:08, 11.0MB/s]
# Downloading:  93%|█████████▎| 1.09G/1.17G [02:59<00:07, 11.1MB/s]
# Downloading:  93%|█████████▎| 1.09G/1.17G [02:59<00:07, 11.0MB/s]
# Downloading:  93%|█████████▎| 1.09G/1.17G [02:59<00:07, 10.8MB/s]
# Downloading:  93%|█████████▎| 1.09G/1.17G [02:59<00:07, 11.1MB/s]
# Downloading:  93%|█████████▎| 1.09G/1.17G [02:59<00:06, 11.5MB/s]
# Downloading:  93%|█████████▎| 1.10G/1.17G [03:00<00:06, 11.5MB/s]
# Downloading:  94%|█████████▎| 1.10G/1.17G [03:00<00:06, 11.5MB/s]
# Downloading:  94%|█████████▍| 1.10G/1.17G [03:00<00:06, 11.8MB/s]
# Downloading:  94%|█████████▍| 1.10G/1.17G [03:00<00:05, 11.8MB/s]
# Downloading:  94%|█████████▍| 1.10G/1.17G [03:00<00:05, 11.7MB/s]
# Downloading:  94%|█████████▍| 1.11G/1.17G [03:01<00:06, 11.0MB/s]
# Downloading:  77%|███████▋  | 749M/975M [01:16<00:20, 11.2MB/s]
# Downloading:  77%|███████▋  | 751M/975M [01:16<00:18, 12.0MB/s]
# Downloading:  95%|█████████▍| 1.11G/1.17G [03:01<00:08, 7.32MB/s]
# Downloading:  77%|███████▋  | 755M/975M [01:16<00:19, 11.2MB/s]
# Downloading:  95%|█████████▍| 1.11G/1.17G [03:01<00:07, 7.94MB/s]
# Downloading:  95%|█████████▌| 1.12G/1.17G [03:02<00:05, 9.84MB/s]
# Downloading:  96%|█████████▌| 1.12G/1.17G [03:02<00:04, 10.6MB/s]
# Downloading:  96%|█████████▌| 1.12G/1.17G [03:02<00:04, 10.4MB/s]
# Downloading:  79%|███████▊  | 765M/975M [01:17<00:28, 7.37MB/s]
# Downloading:  96%|█████████▌| 1.12G/1.17G [03:03<00:06, 7.73MB/s]
# Downloading:  96%|█████████▌| 1.13G/1.17G [03:03<00:05, 8.53MB/s]
# Downloading:  79%|███████▉  | 773M/975M [01:18<00:23, 8.48MB/s]
# Downloading:  96%|█████████▋| 1.13G/1.17G [03:03<00:06, 6.67MB/s]
# Downloading:  96%|█████████▋| 1.13G/1.17G [03:04<00:06, 6.79MB/s]
# Downloading:  97%|█████████▋| 1.13G/1.17G [03:04<00:05, 7.61MB/s]
# Downloading:  80%|████████  | 781M/975M [01:19<00:20, 9.58MB/s]
# Downloading:  97%|█████████▋| 1.13G/1.17G [03:04<00:06, 6.03MB/s]
# Downloading:  81%|████████  | 785M/975M [01:19<00:18, 10.4MB/s]
# Downloading:  97%|█████████▋| 1.14G/1.17G [03:05<00:06, 5.74MB/s]
# Downloading:  97%|█████████▋| 1.14G/1.17G [03:05<00:04, 6.75MB/s]
# Downloading:  97%|█████████▋| 1.14G/1.17G [03:05<00:04, 7.13MB/s]
# Downloading:  98%|█████████▊| 1.14G/1.17G [03:05<00:03, 7.76MB/s]
# Downloading:  98%|█████████▊| 1.15G/1.17G [03:06<00:02, 9.23MB/s]
# Downloading:  98%|█████████▊| 1.15G/1.17G [03:06<00:02, 9.23MB/s]
# Downloading:  98%|█████████▊| 1.15G/1.17G [03:06<00:01, 10.8MB/s]
# Downloading:  99%|█████████▊| 1.16G/1.17G [03:07<00:01, 9.66MB/s]
# Downloading:  99%|█████████▉| 1.16G/1.17G [03:07<00:01, 11.1MB/s]
# Downloading:  99%|█████████▉| 1.16G/1.17G [03:07<00:00, 10.7MB/s]
# Downloading:  99%|█████████▉| 1.16G/1.17G [03:07<00:00, 10.5MB/s]
# Downloading: 100%|█████████▉| 1.17G/1.17G [03:07<00:00, 12.1MB/s]
# Downloading: 100%|█████████▉| 1.17G/1.17G [03:08<00:00, 11.2MB/s]
# Downloading: 100%|█████████▉| 1.17G/1.17G [03:08<00:00, 10.7MB/s]
# Downloading: 100%|██████████| 1.17G/1.17G [03:08<00:00, 6.22MB/s]
#
# Downloading:  84%|████████▍ | 821M/975M [01:23<00:14, 10.6MB/s]
# MD5 checksumming:   1%|▏         | 15.9M/1.17G [00:00<00:07, 159MB/s]
# MD5 checksumming:   5%|▌         | 61.3M/1.17G [00:00<00:05, 197MB/s]
# Downloading:  84%|████████▍ | 823M/975M [01:23<00:17, 8.69MB/s]
# MD5 checksumming:  13%|█▎        | 154M/1.17G [00:00<00:03, 278MB/s]
# MD5 checksumming:  17%|█▋        | 201M/1.17G [00:00<00:03, 317MB/s]
# Downloading:  85%|████████▍ | 825M/975M [01:24<00:17, 8.37MB/s]
# Downloading:  85%|████████▍ | 826M/975M [01:24<00:17, 8.34MB/s]
# MD5 checksumming:  28%|██▊       | 333M/1.17G [00:00<00:02, 386MB/s]
# MD5 checksumming:  32%|███▏      | 376M/1.17G [00:00<00:02, 397MB/s]
# Downloading:  85%|████████▍ | 828M/975M [01:24<00:17, 8.15MB/s]
# MD5 checksumming:  40%|███▉      | 466M/1.17G [00:01<00:01, 422MB/s]
# Downloading:  85%|████████▌ | 832M/975M [01:24<00:15, 8.99MB/s]
# MD5 checksumming:  47%|████▋     | 556M/1.17G [00:01<00:01, 433MB/s]
# MD5 checksumming:  51%|█████     | 601M/1.17G [00:01<00:01, 437MB/s]
# Downloading:  86%|████████▌ | 835M/975M [01:25<00:14, 9.69MB/s]
# MD5 checksumming:  59%|█████▉    | 695M/1.17G [00:01<00:01, 440MB/s]
# Downloading:  86%|████████▌ | 838M/975M [01:25<00:13, 10.2MB/s]
# MD5 checksumming:  67%|██████▋   | 786M/1.17G [00:01<00:00, 425MB/s]
# MD5 checksumming:  71%|███████   | 829M/1.17G [00:01<00:00, 415MB/s]
# Downloading:  86%|████████▋ | 841M/975M [01:25<00:12, 10.7MB/s]
# MD5 checksumming:  78%|███████▊  | 912M/1.17G [00:02<00:00, 397MB/s]
# Downloading:  87%|████████▋ | 844M/975M [01:25<00:11, 11.0MB/s]
# MD5 checksumming:  85%|████████▍ | 992M/1.17G [00:02<00:00, 396MB/s]
# MD5 checksumming:  88%|████████▊ | 1.03G/1.17G [00:02<00:00, 397MB/s]
# Downloading:  87%|████████▋ | 847M/975M [01:26<00:11, 11.2MB/s]
# MD5 checksumming:  96%|█████████▌| 1.12G/1.17G [00:02<00:00, 426MB/s]
# MD5 checksumming: 100%|██████████| 1.17G/1.17G [00:02<00:00, 423MB/s]
# Downloading:  88%|████████▊ | 862M/975M [01:27<00:09, 12.5MB/s]
# Downloading:  90%|████████▉ | 875M/975M [01:28<00:08, 12.2MB/s]
# Downloading:  90%|████████▉ | 877M/975M [01:28<00:08, 12.1MB/s]
# Downloading:  90%|█████████ | 881M/975M [01:28<00:07, 12.2MB/s]
# Downloading:  91%|█████████ | 885M/975M [01:29<00:08, 11.2MB/s]
# Downloading:  91%|█████████ | 889M/975M [01:29<00:07, 12.1MB/s]
# Downloading:  92%|█████████▏| 893M/975M [01:29<00:06, 12.3MB/s]
# Downloading:  92%|█████████▏| 895M/975M [01:30<00:07, 11.3MB/s]
# Downloading:  92%|█████████▏| 900M/975M [01:30<00:06, 12.5MB/s]
# Downloading:  92%|█████████▏| 902M/975M [01:30<00:06, 11.4MB/s]
# Downloading:  93%|█████████▎| 906M/975M [01:31<00:05, 12.4MB/s]
# Downloading:  93%|█████████▎| 908M/975M [01:31<00:05, 11.2MB/s]
# Downloading:  94%|█████████▎| 912M/975M [01:31<00:05, 12.3MB/s]
# Downloading:  94%|█████████▍| 914M/975M [01:31<00:05, 11.3MB/s]
# Downloading:  94%|█████████▍| 919M/975M [01:32<00:04, 12.3MB/s]
# Downloading:  94%|█████████▍| 921M/975M [01:32<00:04, 11.1MB/s]
# Downloading:  95%|█████████▍| 923M/975M [01:32<00:04, 11.2MB/s]
# Downloading:  95%|█████████▍| 925M/975M [01:32<00:04, 12.1MB/s]
# Downloading:  95%|█████████▌| 927M/975M [01:32<00:04, 10.9MB/s]
# Downloading:  96%|█████████▌| 931M/975M [01:33<00:03, 11.7MB/s]
# Downloading:  96%|█████████▌| 933M/975M [01:33<00:03, 11.0MB/s]
# Downloading:  96%|█████████▌| 935M/975M [01:33<00:03, 11.6MB/s]
# Downloading:  96%|█████████▌| 937M/975M [01:33<00:03, 11.8MB/s]
# Downloading:  96%|█████████▋| 940M/975M [01:34<00:03, 11.0MB/s]
# Downloading:  97%|█████████▋| 942M/975M [01:34<00:02, 11.7MB/s]
# Downloading:  97%|█████████▋| 944M/975M [01:34<00:02, 11.4MB/s]
# Downloading:  97%|█████████▋| 948M/975M [01:34<00:02, 11.8MB/s]
# Downloading:  97%|█████████▋| 950M/975M [01:34<00:02, 11.6MB/s]
# Downloading:  98%|█████████▊| 952M/975M [01:35<00:02, 11.2MB/s]
# Downloading:  98%|█████████▊| 954M/975M [01:35<00:01, 11.7MB/s]
# Downloading:  98%|█████████▊| 956M/975M [01:35<00:01, 11.8MB/s]
# Downloading:  98%|█████████▊| 958M/975M [01:35<00:01, 10.9MB/s]
# Downloading:  99%|█████████▊| 960M/975M [01:35<00:01, 11.8MB/s]
# Downloading:  99%|█████████▊| 963M/975M [01:35<00:01, 12.1MB/s]
# Downloading:  99%|█████████▉| 965M/975M [01:36<00:00, 10.9MB/s]
# Downloading:  99%|█████████▉| 967M/975M [01:36<00:00, 11.9MB/s]
# Downloading:  99%|█████████▉| 969M/975M [01:36<00:00, 12.1MB/s]
# Downloading:   6%|▌         | 68.2M/1.21G [00:09<02:03, 9.22MB/s]
# Downloading: 100%|█████████▉| 971M/975M [01:36<00:00, 11.0MB/s]
# Downloading: 100%|█████████▉| 973M/975M [01:36<00:00, 11.7MB/s]
# Downloading: 100%|██████████| 975M/975M [01:37<00:00, 10.1MB/s]
# Downloading: 100%|██████████| 975M/975M [01:37<00:00, 10.0MB/s]
#
# MD5 checksumming:   0%|          | 0.00/975M [00:00<?, ?B/s]
# Downloading:   6%|▌         | 74.4M/1.21G [00:09<02:01, 9.32MB/s]
# Downloading:   6%|▋         | 75.5M/1.21G [00:09<01:58, 9.58MB/s]
# Downloading:   6%|▋         | 76.5M/1.21G [00:10<02:01, 9.33MB/s]
# Downloading:   6%|▋         | 77.6M/1.21G [00:10<02:05, 8.99MB/s]
# MD5 checksumming:  19%|█▊        | 181M/975M [00:00<00:02, 304MB/s]
# Downloading:   7%|▋         | 79.7M/1.21G [00:10<02:02, 9.20MB/s]
# MD5 checksumming:  27%|██▋       | 266M/975M [00:00<00:02, 354MB/s]
# Downloading:   7%|▋         | 81.8M/1.21G [00:10<01:59, 9.40MB/s]
# MD5 checksumming:  36%|███▋      | 354M/975M [00:00<00:01, 391MB/s]
# Downloading:   7%|▋         | 82.8M/1.21G [00:10<01:59, 9.38MB/s]
# Downloading:   7%|▋         | 83.9M/1.21G [00:10<01:56, 9.65MB/s]
# Downloading:   7%|▋         | 84.9M/1.21G [00:11<02:05, 8.93MB/s]
# MD5 checksumming:  54%|█████▍    | 527M/975M [00:01<00:01, 423MB/s]
# Downloading:   7%|▋         | 87.0M/1.21G [00:11<02:01, 9.20MB/s]
# Downloading:   7%|▋         | 88.1M/1.21G [00:11<01:57, 9.51MB/s]
# Downloading:   7%|▋         | 89.1M/1.21G [00:11<01:57, 9.52MB/s]
# MD5 checksumming:  71%|███████▏  | 696M/975M [00:01<00:00, 411MB/s]
# Downloading:   7%|▋         | 90.2M/1.21G [00:11<02:11, 8.48MB/s]
# MD5 checksumming:  80%|████████  | 781M/975M [00:01<00:00, 414MB/s]
# Downloading:   8%|▊         | 92.3M/1.21G [00:11<02:05, 8.86MB/s]
# MD5 checksumming:  89%|████████▉ | 867M/975M [00:02<00:00, 422MB/s]
# Downloading:   8%|▊         | 94.4M/1.21G [00:12<02:09, 8.62MB/s]
# MD5 checksumming: 100%|██████████| 975M/975M [00:02<00:00, 409MB/s]
# Downloading: 100%|██████████| 1.21G/1.21G [02:11<00:00, 9.20MB/s]
# MD5 checksumming: 100%|██████████| 1.21G/1.21G [00:02<00:00, 466MB/s]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# <ipython-input-28-a734f8dc64dc> in <module>()
#       3 #%%capture
#       4
# ----> 5 api.download_all(products_df_sorted.index,"Data/novo/")
#       6
#       7
#
# /usr/local/lib/python3.6/dist-packages/sentinelsat/sentinel.py in download_all(self, products, directory_path, max_attempts, checksum, n_concurrent_dl, lta_retry_delay)
#     777
#     778             for dl_task in concurrent.futures.as_completed(dl_tasks):
# --> 779                 if not dl_task.exception() and dl_task.result():
#     780                     product_info = dl_task.result()
#     781                     downloaded_prods[product_info["id"]] = product_info
#
# /usr/lib/python3.6/concurrent/futures/_base.py in exception(self, timeout)
#     454         with self._condition:
#     455             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
# --> 456                 raise CancelledError()
#     457             elif self._state == FINISHED:
#     458                 return self._exception
#
# CancelledError:

# %%
#api.download(S2B_MSIL1C_20180322T100019_N0206_R122_T33TUL_20180322T120713	,"Data/Inputs/")

# %% [markdown]
# ### Finding our input data
#
# We search for and list our input data. It should be in the form of zipped Sentinel2-files.  If we want to preprocess them for training, we will have to unzip them later, but if all we want to do is the superresolution itself, that will not be necessary.

# %%
import glob
image_zips=(glob.glob("Data/Inputs/*.zip"))
image_zips
# Out:
# ['Data/Inputs/S2A_MSIL1C_20190401T100031_N0207_R122_T33TWM_20190401T105727.zip']

# %% [markdown]
# ---
#
#
#
# ### Application A: Training
#
# The model is trained using patches which are randomly extracted from the input images.
# For the training process, three functions are relevant:
#
# *   Preprocessing:
#       * `readS2fromFile`: This function extracts a large number of random image patches from the input files and saves them in a new directory `train` or `train60`.
#       * `create_random`: This function indexes the image patches and randomly splits the index into a training and a testing dataset.
# *   Training:
#       * `train_DSen2`: Loads the image patches and trains a model from scratch or from a previously created weights file.
#
# We load these functions from the `/python` directory.

# %%
import sys
sys.path.append("DSen2/python")
from create_patches import readS2fromFile
from create_random import create_random
from supres_train import train_DSen2
#from patches import recompose_images, OpenDataFilesTest, OpenDataFiles
#from DSen2Net import s2model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Extracting the Files
#
# For creating the training files, the input files need to be unzipped. A bit annoying, but a simple task.
# We extract all our files into the `Data/Training` folder

# %%
import zipfile
for i in range(0, len(image_zips)):
  with zipfile.ZipFile(image_zips[i], 'r') as zip_ref:
      zip_ref.extractall("Data/Training")

# %%
train_files=glob.glob("Data/Training/*SAFE",recursive=True)
train_files
# Out:
# ['Data/Training/S2A_MSIL1C_20190401T100031_N0207_R122_T33TWM_20190401T105727.SAFE']

# %% [markdown]
# ####  Setting the parameters

# %% [markdown]
# We have to set a number of parameters for the preprocessing of the data.
# * **data_files**: The list of files from which tiles will be created. They will be processed iteratively.
# * **training_path**: The directory which contains the unzipped images. This is also the directory into which outputs will be saved.
# * **test_data**: If `true` stores test patches in a separate dir?
# * **roi_x_y**: A string which sets the region of interest (x_1,y_1,x_2,y_2) to extract as pixels locations on the 10m bands.
# * **write_images**: If `true`, write PNG images into the output folder.
# * **run_60**: If `true`, creates patches also from the 60m channels. This basically determines for which network (60m or 20m) we are creating the patches, and therefore we will also use this parameter later as a switch for training the model.
# * **NR_CROP**: The number of image patches to be extracted per image
# * **split_ratio**: The proportion of patches that goes into the testing partition.
#
# In addition, there are certain parameters for the training itself.
#
# * **deep**: Train a *very* deep network (VDSen2)? If `False`, trains a deep network.
# * **model_name**: The name for the output model. This is the name under which the network weights and associated files will be output in a subdirectory `/network_data` withing the **training_path**
# *   **SCALE**: A factor by which the raw reflectance values are divided by for "numerical stability".
# *   **lr**: The base learning rate. When plateauing, it will be lowered by a callback.
# * **n_epochs**: The number of epochs to train the model for.
# * **resume_file**: This should be a string of the path to the weights we want to continue training from. Note that the weights file must match the model depth (as set by **deep**) and input shape (as set by **run_60**).
# If we want to train from scratch, we pass an empty string.

# %% [markdown]
# Here, we set **`run_60`** and **`deep`** to `True`, and we will resume from the file `"DSen2/models/s2_030_lr_1e-05.hdf5"` and tune it to a new model which will be saved into `Data/Training/network_data/GutesModell.hdf5`,

# %%
##For the Preprocessing
data_files=train_files
training_path="Data/Training/"
test_data=False  
roi_x_y=""
write_images=True
run_60=True
NR_CROP=600
split_ratio=0.1

##For the Training
deep=False
model_name = "nov_model60"
SCALE = 2000
lr = 1e-4
n_epochs=4096


##Use this to train with the pre-trained DSen2/VDSen2 weights
if(deep):
  if(run_60):
    resume_file="DSen2/models/s2_034_lr_1e-04.hdf5"  
  else:
    resume_file="DSen2/models/s2_033_lr_1e-04.hdf5"  
else:
  if(run_60):
    resume_file="DSen2/models/s2_030_lr_1e-05.hdf5"
  else:
    resume_file="DSen2/models/s2_032_lr_1e-04.hdf5"

#uncomment to train from scratch or from a previous weight file
#resume_file= "Data/Training/network_data/nov_model60.hdf5"
#resume_file="Path/to/the/model.hdf5"

# %% [markdown]
# #### Creating the patches
#
# Now we want to create the test patches. The function `readS2fromFile` iteratively reads in the Sentinel-2 images , extracts random test patches, and saves them into the `/training_path` where output folders `/train` or `/train_60` (if **`run_60`**) will be created. Afterwards, the input images themselves are strictly not necessary anymore, and we could delete them, but if we want to try the superresolution on them we should still keep them around.

# %%
#for i in range(0, len(data_files)):
#  data_file=data_files[i]

readS2fromFile(data_files=data_files,
                test_data=test_data,
                roi_x_y=roi_x_y,
                save_prefix=training_path,
                write_images=write_images,
                run_60=run_60,
                NR_CROP=NR_CROP)
# Out:
# Data/Training/
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Success.

# %% [markdown]
# #### Indexing and Splitting
#
# The `create_random` will create an index of the training patches, but it does **not** do this by searching for the files we have created in the previous step. Rather, the number of patches must be given to the function. We can simply derive it from multiplying the parameter **`NR_CROP`** we set previously by the number of images.
# It will create a file `val_index.npy` which will be saved within the specified folders subdirectories which we just created in the previous step, either `/train` or `/train_60` depending on whether we use the `run_60` switch or not (to ensure consistency, we just reuse the **`run_60`** we set previously in this script).

# %%
###CREATE THE TRAIN INDEX AND SPLIT ###
create_random( size=len(data_files)*NR_CROP,ratio=split_ratio,out_path=training_path, run_60=run_60)
# Out:
# Full no of samples: 600
# Validation samples: 60
# Number of iterations: 61

# %% [markdown]
# function ClickConnect(){
#     document.querySelector("colab-connect-button").click()
#     console.log("Clicked on connect button");
# }
# setInterval(ClickConnect,60000)

# %% [markdown]
# ####Training
#
# Training is not complicated. We have set all of the parameters already.
#
# The inputs will be read from our training directory, specifically the subfolders `/train` or `/train60` (here, again, our **`run_60`** parameter comes into play), and split using `val_index.npy` we just put there.
# The outputs will be saved within our training directory within a newly created subfolder `/network_data`.

# %%
import time
start_time = time.time()
train_DSen2(model_name=model_name,path=training_path,run_60=run_60,deep=deep,resume_file=resume_file,SCALE=SCALE,lr=lr,n_epochs=n_epochs)
Deep_Time= time.time() - start_time
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Symbolic Model Created.
# Model compiled.
# Will resume from the weights DSen2/models/s2_030_lr_1e-05.hdf5
# Changing the model Name to: nov_model60
# Loading the training data...from...
# Data/Training/
# /tensorflow-1.15.2/python3.6/keras/callbacks/callbacks.py:998: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# Loaded 600 patches for training.
# Training starts...
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Streaming output truncated to the last 5000 lines.
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7435e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2570e-05
#
# Epoch 02847: val_loss did not improve from 0.00515
# Epoch 2848/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7428e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2548e-05
#
# Epoch 02848: val_loss did not improve from 0.00515
# Epoch 2849/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7428e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2549e-05
#
# Epoch 02849: val_loss did not improve from 0.00515
# Epoch 2850/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7428e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2538e-05
#
# Epoch 02850: val_loss did not improve from 0.00515
# Epoch 2851/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7421e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2559e-05
#
# Epoch 02851: val_loss did not improve from 0.00515
# Epoch 2852/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7425e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2544e-05
#
# Epoch 02852: val_loss did not improve from 0.00515
# Epoch 2853/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7418e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2592e-05
#
# Epoch 02853: val_loss did not improve from 0.00515
# Epoch 2854/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7435e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2539e-05
#
# Epoch 02854: val_loss did not improve from 0.00515
# Epoch 2855/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7427e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2569e-05
#
# Epoch 02855: val_loss did not improve from 0.00515
# Epoch 2856/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7435e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2544e-05
#
# Epoch 02856: val_loss did not improve from 0.00515
# Epoch 2857/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7418e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2540e-05
#
# Epoch 02857: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2858/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7412e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2582e-05
#
# Epoch 02858: val_loss did not improve from 0.00515
# Epoch 2859/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7442e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2558e-05
#
# Epoch 02859: val_loss did not improve from 0.00515
# Epoch 2860/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7427e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2542e-05
#
# Epoch 02860: val_loss did not improve from 0.00515
# Epoch 2861/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7418e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2540e-05
#
# Epoch 02861: val_loss did not improve from 0.00515
# Epoch 2862/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7408e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2550e-05
#
# Epoch 02862: val_loss did not improve from 0.00515
# Epoch 2863/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7418e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2543e-05
#
# Epoch 02863: val_loss did not improve from 0.00515
# Epoch 2864/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7403e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2559e-05
#
# Epoch 02864: val_loss did not improve from 0.00515
# Epoch 2865/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7408e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2533e-05
#
# Epoch 02865: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2866/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7407e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2580e-05
#
# Epoch 02866: val_loss did not improve from 0.00515
# Epoch 2867/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7416e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2548e-05
#
# Epoch 02867: val_loss did not improve from 0.00515
# Epoch 2868/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7421e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2597e-05
#
# Epoch 02868: val_loss did not improve from 0.00515
# Epoch 2869/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7411e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2527e-05
#
# Epoch 02869: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2870/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7404e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2559e-05
#
# Epoch 02870: val_loss did not improve from 0.00515
# Epoch 2871/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7404e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2543e-05
#
# Epoch 02871: val_loss did not improve from 0.00515
# Epoch 2872/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7400e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2536e-05
#
# Epoch 02872: val_loss did not improve from 0.00515
# Epoch 2873/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7395e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2555e-05
#
# Epoch 02873: val_loss did not improve from 0.00515
# Epoch 2874/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7398e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2528e-05
#
# Epoch 02874: val_loss did not improve from 0.00515
# Epoch 2875/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7393e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2544e-05
#
# Epoch 02875: val_loss did not improve from 0.00515
# Epoch 2876/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7401e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2556e-05
#
# Epoch 02876: val_loss did not improve from 0.00515
# Epoch 2877/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7404e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2555e-05
#
# Epoch 02877: val_loss did not improve from 0.00515
# Epoch 2878/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7396e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2549e-05
#
# Epoch 02878: val_loss did not improve from 0.00515
# Epoch 2879/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7390e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2536e-05
#
# Epoch 02879: val_loss did not improve from 0.00515
# Epoch 2880/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7389e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2527e-05
#
# Epoch 02880: val_loss did not improve from 0.00515
# Epoch 2881/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7387e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2545e-05
#
# Epoch 02881: val_loss did not improve from 0.00515
# Epoch 2882/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7389e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2528e-05
#
# Epoch 02882: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2883/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7382e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2560e-05
#
# Epoch 02883: val_loss did not improve from 0.00515
# Epoch 2884/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7390e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2527e-05
#
# Epoch 02884: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2885/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7386e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2561e-05
#
# Epoch 02885: val_loss did not improve from 0.00515
# Epoch 2886/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7395e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2537e-05
#
# Epoch 02886: val_loss did not improve from 0.00515
# Epoch 2887/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7400e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2544e-05
#
# Epoch 02887: val_loss did not improve from 0.00515
# Epoch 2888/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7388e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2515e-05
#
# Epoch 02888: val_loss did not improve from 0.00515
# Epoch 2889/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7379e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2540e-05
#
# Epoch 02889: val_loss did not improve from 0.00515
# Epoch 2890/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7399e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2562e-05
#
# Epoch 02890: val_loss did not improve from 0.00515
# Epoch 2891/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7418e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2544e-05
#
# Epoch 02891: val_loss did not improve from 0.00515
# Epoch 2892/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7375e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2562e-05
#
# Epoch 02892: val_loss did not improve from 0.00515
# Epoch 2893/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7387e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2517e-05
#
# Epoch 02893: val_loss did not improve from 0.00515
# Epoch 2894/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7369e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2567e-05
#
# Epoch 02894: val_loss did not improve from 0.00515
# Epoch 2895/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7377e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2524e-05
#
# Epoch 02895: val_loss did not improve from 0.00515
# Epoch 2896/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7370e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2529e-05
#
# Epoch 02896: val_loss did not improve from 0.00515
# Epoch 2897/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7371e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2541e-05
#
# Epoch 02897: val_loss did not improve from 0.00515
# Epoch 2898/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7379e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2619e-05
#
# Epoch 02898: val_loss did not improve from 0.00515
# Epoch 2899/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7406e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2524e-05
#
# Epoch 02899: val_loss did not improve from 0.00515
# Epoch 2900/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7372e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2555e-05
#
# Epoch 02900: val_loss did not improve from 0.00515
# Epoch 2901/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7380e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2545e-05
#
# Epoch 02901: val_loss did not improve from 0.00515
# Epoch 2902/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7382e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2553e-05
#
# Epoch 02902: val_loss did not improve from 0.00515
# Epoch 2903/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7368e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2518e-05
#
# Epoch 02903: val_loss did not improve from 0.00515
# Epoch 2904/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7362e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2567e-05
#
# Epoch 02904: val_loss did not improve from 0.00515
# Epoch 2905/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7368e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2722e-05
#
# Epoch 02905: val_loss did not improve from 0.00515
# Epoch 2906/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7460e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2628e-05
#
# Epoch 02906: val_loss did not improve from 0.00515
# Epoch 2907/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7408e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2515e-05
#
# Epoch 02907: val_loss did not improve from 0.00515
# Epoch 2908/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7358e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2537e-05
#
# Epoch 02908: val_loss did not improve from 0.00515
# Epoch 2909/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7361e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2594e-05
#
# Epoch 02909: val_loss did not improve from 0.00515
# Epoch 2910/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7375e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2533e-05
#
# Epoch 02910: val_loss did not improve from 0.00515
# Epoch 2911/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7356e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2609e-05
#
# Epoch 02911: val_loss did not improve from 0.00515
# Epoch 2912/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7390e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2527e-05
#
# Epoch 02912: val_loss did not improve from 0.00515
# Epoch 2913/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7358e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2503e-05
#
# Epoch 02913: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2914/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7346e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2517e-05
#
# Epoch 02914: val_loss did not improve from 0.00515
# Epoch 2915/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7344e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2506e-05
#
# Epoch 02915: val_loss did not improve from 0.00515
# Epoch 2916/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7343e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2517e-05
#
# Epoch 02916: val_loss did not improve from 0.00515
# Epoch 2917/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7341e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2531e-05
#
# Epoch 02917: val_loss did not improve from 0.00515
# Epoch 2918/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7356e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2505e-05
#
# Epoch 02918: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2919/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7344e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2556e-05
#
# Epoch 02919: val_loss did not improve from 0.00515
# Epoch 2920/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7360e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2518e-05
#
# Epoch 02920: val_loss did not improve from 0.00515
# Epoch 2921/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7359e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2543e-05
#
# Epoch 02921: val_loss did not improve from 0.00515
# Epoch 2922/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7361e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2525e-05
#
# Epoch 02922: val_loss did not improve from 0.00515
# Epoch 2923/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7344e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2500e-05
#
# Epoch 02923: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2924/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7334e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2544e-05
#
# Epoch 02924: val_loss did not improve from 0.00515
# Epoch 2925/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7348e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2509e-05
#
# Epoch 02925: val_loss did not improve from 0.00515
# Epoch 2926/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7342e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2500e-05
#
# Epoch 02926: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2927/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7327e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2508e-05
#
# Epoch 02927: val_loss did not improve from 0.00515
# Epoch 2928/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7342e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2518e-05
#
# Epoch 02928: val_loss did not improve from 0.00515
# Epoch 2929/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7340e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2512e-05
#
# Epoch 02929: val_loss did not improve from 0.00515
# Epoch 2930/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7360e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2546e-05
#
# Epoch 02930: val_loss did not improve from 0.00515
# Epoch 2931/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7345e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2521e-05
#
# Epoch 02931: val_loss did not improve from 0.00515
# Epoch 2932/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7340e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2536e-05
#
# Epoch 02932: val_loss did not improve from 0.00515
# Epoch 2933/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7336e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2512e-05
#
# Epoch 02933: val_loss did not improve from 0.00515
# Epoch 2934/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7337e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2523e-05
#
# Epoch 02934: val_loss did not improve from 0.00515
# Epoch 2935/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7335e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2520e-05
#
# Epoch 02935: val_loss did not improve from 0.00515
# Epoch 2936/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7331e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2497e-05
#
# Epoch 02936: val_loss did not improve from 0.00515
# Epoch 2937/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7323e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2502e-05
#
# Epoch 02937: val_loss did not improve from 0.00515
# Epoch 2938/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7324e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2503e-05
#
# Epoch 02938: val_loss did not improve from 0.00515
# Epoch 2939/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7317e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2493e-05
#
# Epoch 02939: val_loss did not improve from 0.00515
# Epoch 2940/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7313e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2506e-05
#
# Epoch 02940: val_loss did not improve from 0.00515
# Epoch 2941/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7313e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2501e-05
#
# Epoch 02941: val_loss did not improve from 0.00515
# Epoch 2942/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7327e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2533e-05
#
# Epoch 02942: val_loss did not improve from 0.00515
# Epoch 2943/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7331e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2535e-05
#
# Epoch 02943: val_loss did not improve from 0.00515
# Epoch 2944/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7353e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2542e-05
#
# Epoch 02944: val_loss did not improve from 0.00515
# Epoch 2945/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7334e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2494e-05
#
# Epoch 02945: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2946/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7311e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2509e-05
#
# Epoch 02946: val_loss did not improve from 0.00515
# Epoch 2947/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7316e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2496e-05
#
# Epoch 02947: val_loss did not improve from 0.00515
# Epoch 2948/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7312e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2504e-05
#
# Epoch 02948: val_loss did not improve from 0.00515
# Epoch 2949/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7313e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2500e-05
#
# Epoch 02949: val_loss did not improve from 0.00515
# Epoch 2950/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7311e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2519e-05
#
# Epoch 02950: val_loss did not improve from 0.00515
# Epoch 2951/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7335e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2503e-05
#
# Epoch 02951: val_loss did not improve from 0.00515
# Epoch 2952/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7306e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2504e-05
#
# Epoch 02952: val_loss did not improve from 0.00515
# Epoch 2953/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7300e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2492e-05
#
# Epoch 02953: val_loss did not improve from 0.00515
# Epoch 2954/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7311e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2515e-05
#
# Epoch 02954: val_loss did not improve from 0.00515
# Epoch 2955/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7303e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2516e-05
#
# Epoch 02955: val_loss did not improve from 0.00515
# Epoch 2956/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7312e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2498e-05
#
# Epoch 02956: val_loss did not improve from 0.00515
# Epoch 2957/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7299e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2481e-05
#
# Epoch 02957: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2958/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7301e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2518e-05
#
# Epoch 02958: val_loss did not improve from 0.00515
# Epoch 2959/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7308e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2486e-05
#
# Epoch 02959: val_loss did not improve from 0.00515
# Epoch 2960/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7302e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2486e-05
#
# Epoch 02960: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2961/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7292e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2487e-05
#
# Epoch 02961: val_loss did not improve from 0.00515
# Epoch 2962/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7292e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2513e-05
#
# Epoch 02962: val_loss did not improve from 0.00515
# Epoch 2963/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7306e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2516e-05
#
# Epoch 02963: val_loss did not improve from 0.00515
# Epoch 2964/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7297e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2494e-05
#
# Epoch 02964: val_loss did not improve from 0.00515
# Epoch 2965/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7296e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2504e-05
#
# Epoch 02965: val_loss did not improve from 0.00515
# Epoch 2966/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7291e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2506e-05
#
# Epoch 02966: val_loss did not improve from 0.00515
# Epoch 2967/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7291e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2491e-05
#
# Epoch 02967: val_loss did not improve from 0.00515
# Epoch 2968/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7301e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2635e-05
#
# Epoch 02968: val_loss did not improve from 0.00515
# Epoch 2969/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7340e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2488e-05
#
# Epoch 02969: val_loss did not improve from 0.00515
# Epoch 2970/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7290e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2492e-05
#
# Epoch 02970: val_loss did not improve from 0.00515
# Epoch 2971/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7282e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2490e-05
#
# Epoch 02971: val_loss did not improve from 0.00515
# Epoch 2972/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7283e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2488e-05
#
# Epoch 02972: val_loss did not improve from 0.00515
# Epoch 2973/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7282e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2483e-05
#
# Epoch 02973: val_loss did not improve from 0.00515
# Epoch 2974/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7283e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2509e-05
#
# Epoch 02974: val_loss did not improve from 0.00515
# Epoch 2975/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7282e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2473e-05
#
# Epoch 02975: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2976/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7284e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2502e-05
#
# Epoch 02976: val_loss did not improve from 0.00515
# Epoch 2977/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7278e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2486e-05
#
# Epoch 02977: val_loss did not improve from 0.00515
# Epoch 2978/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7290e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2491e-05
#
# Epoch 02978: val_loss did not improve from 0.00515
# Epoch 2979/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7279e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2481e-05
#
# Epoch 02979: val_loss did not improve from 0.00515
# Epoch 2980/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7268e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2531e-05
#
# Epoch 02980: val_loss did not improve from 0.00515
# Epoch 2981/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7284e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2507e-05
#
# Epoch 02981: val_loss did not improve from 0.00515
# Epoch 2982/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7277e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2474e-05
#
# Epoch 02982: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 2983/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7288e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2479e-05
#
# Epoch 02983: val_loss did not improve from 0.00515
# Epoch 2984/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7267e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2564e-05
#
# Epoch 02984: val_loss did not improve from 0.00515
# Epoch 2985/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7320e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2544e-05
#
# Epoch 02985: val_loss did not improve from 0.00515
# Epoch 2986/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7291e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2497e-05
#
# Epoch 02986: val_loss did not improve from 0.00515
# Epoch 2987/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7270e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2475e-05
#
# Epoch 02987: val_loss did not improve from 0.00515
# Epoch 2988/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7267e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2477e-05
#
# Epoch 02988: val_loss did not improve from 0.00515
# Epoch 2989/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7272e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2513e-05
#
# Epoch 02989: val_loss did not improve from 0.00515
# Epoch 2990/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7281e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2497e-05
#
# Epoch 02990: val_loss did not improve from 0.00515
# Epoch 2991/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7283e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2569e-05
#
# Epoch 02991: val_loss did not improve from 0.00515
# Epoch 2992/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7287e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2476e-05
#
# Epoch 02992: val_loss did not improve from 0.00515
# Epoch 2993/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7257e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2490e-05
#
# Epoch 02993: val_loss did not improve from 0.00515
# Epoch 2994/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7263e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2473e-05
#
# Epoch 02994: val_loss did not improve from 0.00515
# Epoch 2995/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7256e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2479e-05
#
# Epoch 02995: val_loss did not improve from 0.00515
# Epoch 2996/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7254e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2472e-05
#
# Epoch 02996: val_loss did not improve from 0.00515
# Epoch 2997/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7256e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2514e-05
#
# Epoch 02997: val_loss did not improve from 0.00515
# Epoch 2998/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7266e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2490e-05
#
# Epoch 02998: val_loss did not improve from 0.00515
# Epoch 2999/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7255e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2494e-05
#
# Epoch 02999: val_loss did not improve from 0.00515
# Epoch 3000/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7265e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2535e-05
#
# Epoch 03000: val_loss did not improve from 0.00515
# Epoch 3001/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7275e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2479e-05
#
# Epoch 03001: val_loss did not improve from 0.00515
# Epoch 3002/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7271e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2512e-05
#
# Epoch 03002: val_loss did not improve from 0.00515
# Epoch 3003/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7271e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2474e-05
#
# Epoch 03003: val_loss did not improve from 0.00515
# Epoch 3004/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7257e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2474e-05
#
# Epoch 03004: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 3005/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7240e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2461e-05
#
# Epoch 03005: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 3006/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7239e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2512e-05
#
# Epoch 03006: val_loss did not improve from 0.00515
# Epoch 3007/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7273e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2504e-05
#
# Epoch 03007: val_loss did not improve from 0.00515
# Epoch 3008/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7255e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2473e-05
#
# Epoch 03008: val_loss did not improve from 0.00515
# Epoch 3009/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7253e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2521e-05
#
# Epoch 03009: val_loss did not improve from 0.00515
# Epoch 3010/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7256e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2472e-05
#
# Epoch 03010: val_loss did not improve from 0.00515
# Epoch 3011/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7241e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2468e-05
#
# Epoch 03011: val_loss did not improve from 0.00515
# Epoch 3012/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7244e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2474e-05
#
# Epoch 03012: val_loss did not improve from 0.00515
# Epoch 3013/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7249e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2576e-05
#
# Epoch 03013: val_loss did not improve from 0.00515
# Epoch 3014/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7270e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2463e-05
#
# Epoch 03014: val_loss did not improve from 0.00515
# Epoch 3015/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7238e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2481e-05
#
# Epoch 03015: val_loss did not improve from 0.00515
# Epoch 3016/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7244e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2482e-05
#
# Epoch 03016: val_loss did not improve from 0.00515
# Epoch 3017/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7231e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2456e-05
#
# Epoch 03017: val_loss did not improve from 0.00515
# Epoch 3018/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7231e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2456e-05
#
# Epoch 03018: val_loss did not improve from 0.00515
# Epoch 3019/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7227e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2450e-05
#
# Epoch 03019: val_loss improved from 0.00515 to 0.00515, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 3020/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7230e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2461e-05
#
# Epoch 03020: val_loss did not improve from 0.00515
# Epoch 3021/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7229e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2464e-05
#
# Epoch 03021: val_loss did not improve from 0.00515
# Epoch 3022/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7231e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2474e-05
#
# Epoch 03022: val_loss did not improve from 0.00515
# Epoch 3023/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7232e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2487e-05
#
# Epoch 03023: val_loss did not improve from 0.00515
# Epoch 3024/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7228e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2461e-05
#
# Epoch 03024: val_loss did not improve from 0.00515
# Epoch 3025/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7234e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2466e-05
#
# Epoch 03025: val_loss did not improve from 0.00515
# Epoch 3026/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7224e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2453e-05
#
# Epoch 03026: val_loss did not improve from 0.00515
# Epoch 3027/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7227e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2475e-05
#
# Epoch 03027: val_loss did not improve from 0.00515
# Epoch 3028/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7233e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2475e-05
#
# Epoch 03028: val_loss did not improve from 0.00515
# Epoch 3029/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7245e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2472e-05
#
# Epoch 03029: val_loss did not improve from 0.00515
# Epoch 3030/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7222e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2467e-05
#
# Epoch 03030: val_loss did not improve from 0.00515
# Epoch 3031/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7222e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2470e-05
#
# Epoch 03031: val_loss did not improve from 0.00515
# Epoch 3032/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7214e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2463e-05
#
# Epoch 03032: val_loss did not improve from 0.00515
# Epoch 3033/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7221e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2471e-05
#
# Epoch 03033: val_loss did not improve from 0.00515
# Epoch 3034/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7225e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2467e-05
#
# Epoch 03034: val_loss did not improve from 0.00515
# Epoch 3035/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7218e-05 - val_loss: 0.0052 - val_mean_squared_error: 6.2590e-05
#
# Epoch 03035: val_loss did not improve from 0.00515
# Epoch 3036/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7283e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2541e-05
#
# Epoch 03036: val_loss did not improve from 0.00515
# Epoch 3037/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7240e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2452e-05
#
# Epoch 03037: val_loss did not improve from 0.00515
# Epoch 3038/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7210e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2455e-05
#
# Epoch 03038: val_loss did not improve from 0.00515
# Epoch 3039/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7212e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2461e-05
#
# Epoch 03039: val_loss did not improve from 0.00515
# Epoch 3040/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7236e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2470e-05
#
# Epoch 03040: val_loss did not improve from 0.00515
# Epoch 3041/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7208e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2449e-05
#
# Epoch 03041: val_loss did not improve from 0.00515
# Epoch 3042/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7216e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2473e-05
#
# Epoch 03042: val_loss did not improve from 0.00515
# Epoch 3043/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7221e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2456e-05
#
# Epoch 03043: val_loss did not improve from 0.00515
# Epoch 3044/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7211e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2473e-05
#
# Epoch 03044: val_loss did not improve from 0.00515
# Epoch 3045/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.7211e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2450e-05
#
# Epoch 03045: val_loss did not improve from 0.00515
# Epoch 3046/4096
# ...
# Epoch 4028/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6256e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2140e-05
#
# Epoch 04028: val_loss did not improve from 0.00513
# Epoch 4029/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6250e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2114e-05
#
# Epoch 04029: val_loss did not improve from 0.00513
# Epoch 4030/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6252e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2168e-05
#
# Epoch 04030: val_loss did not improve from 0.00513
# Epoch 4031/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6281e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2112e-05
#
# Epoch 04031: val_loss did not improve from 0.00513
# Epoch 4032/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6247e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2134e-05
#
# Epoch 04032: val_loss did not improve from 0.00513
# Epoch 4033/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6239e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2136e-05
#
# Epoch 04033: val_loss did not improve from 0.00513
# Epoch 4034/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6246e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2102e-05
#
# Epoch 04034: val_loss improved from 0.00513 to 0.00513, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 4035/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6240e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2114e-05
#
# Epoch 04035: val_loss did not improve from 0.00513
# Epoch 4036/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6241e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2108e-05
#
# Epoch 04036: val_loss did not improve from 0.00513
# Epoch 4037/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6236e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2126e-05
#
# Epoch 04037: val_loss did not improve from 0.00513
# Epoch 4038/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6247e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2119e-05
#
# Epoch 04038: val_loss did not improve from 0.00513
# Epoch 4039/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6248e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2131e-05
#
# Epoch 04039: val_loss did not improve from 0.00513
# Epoch 4040/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6240e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2113e-05
#
# Epoch 04040: val_loss did not improve from 0.00513
# Epoch 4041/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6238e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2122e-05
#
# Epoch 04041: val_loss did not improve from 0.00513
# Epoch 4042/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6232e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2102e-05
#
# Epoch 04042: val_loss improved from 0.00513 to 0.00513, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 4043/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6225e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2104e-05
#
# Epoch 04043: val_loss did not improve from 0.00513
# Epoch 4044/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6225e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2101e-05
#
# Epoch 04044: val_loss did not improve from 0.00513
# Epoch 4045/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6233e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2158e-05
#
# Epoch 04045: val_loss did not improve from 0.00513
# Epoch 4046/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6247e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2121e-05
#
# Epoch 04046: val_loss did not improve from 0.00513
# Epoch 4047/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6232e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2133e-05
#
# Epoch 04047: val_loss did not improve from 0.00513
# Epoch 4048/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6232e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2106e-05
#
# Epoch 04048: val_loss did not improve from 0.00513
# Epoch 4049/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6225e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2106e-05
#
# Epoch 04049: val_loss did not improve from 0.00513
# Epoch 4050/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6222e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2125e-05
#
# Epoch 04050: val_loss did not improve from 0.00513
# Epoch 4051/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6227e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2121e-05
#
# Epoch 04051: val_loss did not improve from 0.00513
# Epoch 4052/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6240e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2149e-05
#
# Epoch 04052: val_loss did not improve from 0.00513
# Epoch 4053/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6233e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2236e-05
#
# Epoch 04053: val_loss did not improve from 0.00513
# Epoch 4054/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6293e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2135e-05
#
# Epoch 04054: val_loss did not improve from 0.00513
# Epoch 4055/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6234e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2106e-05
#
# Epoch 04055: val_loss did not improve from 0.00513
# Epoch 4056/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6232e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2213e-05
#
# Epoch 04056: val_loss did not improve from 0.00513
# Epoch 4057/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6282e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2103e-05
#
# Epoch 04057: val_loss did not improve from 0.00513
# Epoch 4058/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6225e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2124e-05
#
# Epoch 04058: val_loss did not improve from 0.00513
# Epoch 4059/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6225e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2132e-05
#
# Epoch 04059: val_loss did not improve from 0.00513
# Epoch 4060/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6235e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2117e-05
#
# Epoch 04060: val_loss did not improve from 0.00513
# Epoch 4061/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6217e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2094e-05
#
# Epoch 04061: val_loss did not improve from 0.00513
# Epoch 4062/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6212e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2089e-05
#
# Epoch 04062: val_loss did not improve from 0.00513
# Epoch 4063/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6208e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2104e-05
#
# Epoch 04063: val_loss did not improve from 0.00513
# Epoch 4064/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6213e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2153e-05
#
# Epoch 04064: val_loss did not improve from 0.00513
# Epoch 4065/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6225e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2103e-05
#
# Epoch 04065: val_loss did not improve from 0.00513
# Epoch 4066/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6210e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2101e-05
#
# Epoch 04066: val_loss did not improve from 0.00513
# Epoch 4067/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6206e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2102e-05
#
# Epoch 04067: val_loss improved from 0.00513 to 0.00513, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 4068/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6203e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2093e-05
#
# Epoch 04068: val_loss did not improve from 0.00513
# Epoch 4069/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6216e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2130e-05
#
# Epoch 04069: val_loss did not improve from 0.00513
# Epoch 4070/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6218e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2099e-05
#
# Epoch 04070: val_loss did not improve from 0.00513
# Epoch 4071/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6225e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2146e-05
#
# Epoch 04071: val_loss did not improve from 0.00513
# Epoch 4072/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6232e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2117e-05
#
# Epoch 04072: val_loss did not improve from 0.00513
# Epoch 4073/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6236e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2107e-05
#
# Epoch 04073: val_loss did not improve from 0.00513
# Epoch 4074/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6201e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2105e-05
#
# Epoch 04074: val_loss did not improve from 0.00513
# Epoch 4075/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6204e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2102e-05
#
# Epoch 04075: val_loss did not improve from 0.00513
# Epoch 4076/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6206e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2121e-05
#
# Epoch 04076: val_loss did not improve from 0.00513
# Epoch 4077/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6208e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2091e-05
#
# Epoch 04077: val_loss improved from 0.00513 to 0.00513, saving model to Data/Training/network_data/nov_model60.hdf5
# Epoch 4078/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6202e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2110e-05
#
# Epoch 04078: val_loss did not improve from 0.00513
# Epoch 4079/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6201e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2094e-05
#
# Epoch 04079: val_loss did not improve from 0.00513
# Epoch 4080/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6201e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2136e-05
#
# Epoch 04080: val_loss did not improve from 0.00513
# Epoch 4081/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6207e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2111e-05
#
# Epoch 04081: val_loss did not improve from 0.00513
# Epoch 4082/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6201e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2118e-05
#
# Epoch 04082: val_loss did not improve from 0.00513
# Epoch 4083/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6203e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2088e-05
#
# Epoch 04083: val_loss did not improve from 0.00513
# Epoch 4084/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6199e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2092e-05
#
# Epoch 04084: val_loss did not improve from 0.00513
# Epoch 4085/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6193e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2091e-05
#
# Epoch 04085: val_loss did not improve from 0.00513
# Epoch 4086/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6199e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2104e-05
#
# Epoch 04086: val_loss did not improve from 0.00513
# Epoch 4087/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6197e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2100e-05
#
# Epoch 04087: val_loss did not improve from 0.00513
# Epoch 4088/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6205e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2134e-05
#
# Epoch 04088: val_loss did not improve from 0.00513
# Epoch 4089/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6216e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2105e-05
#
# Epoch 04089: val_loss did not improve from 0.00513
# Epoch 4090/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6198e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2129e-05
#
# Epoch 04090: val_loss did not improve from 0.00513
# Epoch 4091/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6198e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2112e-05
#
# Epoch 04091: val_loss did not improve from 0.00513
# Epoch 4092/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6193e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2091e-05
#
# Epoch 04092: val_loss did not improve from 0.00513
# Epoch 4093/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6189e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2096e-05
#
# Epoch 04093: val_loss did not improve from 0.00513
# Epoch 4094/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6192e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2084e-05
#
# Epoch 04094: val_loss did not improve from 0.00513
# Epoch 4095/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6188e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2115e-05
#
# Epoch 04095: val_loss did not improve from 0.00513
# Epoch 4096/4096
# 540/540 [==============================] - 4s 8ms/step - loss: 0.0049 - mean_squared_error: 5.6197e-05 - val_loss: 0.0051 - val_mean_squared_error: 6.2092e-05
#
# Epoch 04096: val_loss improved from 0.00513 to 0.00513, saving model to Data/Training/network_data/nov_model60.hdf5

# %% [markdown]
# Training done!

# %%
print(deep_time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-56be207d8607> in <module>()
# ----> 1 print(deep_time)
#
# NameError: name 'deep_time' is not defined

# %% [markdown]
# ---
#
#
#
# ### Application B: Prediction

# %% [markdown]
# For the superresolution we do not require much. Mostly all we need is a list of input images, the weights for our model, and the `DSen2_sl` function.

# %%
# %load_ext autoreload

# %autoreload 2

# %%
import sys
sys.path.append("DSen2/python")
from DSen2_sl import DSen2_sl
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Overview
#
# The function uses reasonble defaults, which is the superresolution of the 20m bands into 10m bands, and combining them with the previous 10m bands into a stack which will be output as a GTiff. Nevertheless, there are a number of adjustments we can make by passing some parameters to the function:
#
# * **input_files**: A list of input files.
# * **output_dir** A directory into which the superresolved images will be output.
# * **model_20_file**  A file to the weights of the 20m model.
# * **model_60_file**: (Optional) If we provide also a file for the 60m model, the 60m bands will also be superresolved and added to the output. Otherwise, only the 20m band will be superresolved.
#
# * **roi_lon_lat**: (Optional) Sets the region of interest to extract, WGS84, decimal notation. lon_1,lat_1,lon_2,lat_2.
# * **roi_x_y**: (Optional) Sets the region of interest to extract as pixels locations on the 10m bands. Use this syntax: x_1,y_1,x_2,y_2.
#
# * **copy_original_bands**: (Optional) Copy the original 10m bands into the new, predicted file?
# * **select_UTM**: (Optional) Manually select a UTM zone to use - otherwise the algorithm will select the UTM zone with the best coverage.
# * **deep**: (Optional) Use a very deep network (VDSen2) instead of a deep network (DSen2)? Note that this must match the weights files provided.

# %% [markdown]
# #### Examples
#
# Here are just some examples of the usage. Note that they will all be saved to the same output file, so executing multiple examples will result in the previous file being overwritten.

# %%
#"DSen2/models/s2_032_lr_1e-04.hdf5"
#1,1,300,300
# roi_x_y=""
"Data/Training/network_data/slo_model.hdf5"
#2196,4392,6588,8784,10980

# %% [markdown]
# ##### Basic Superresolution of just the 20m model
# This is the basic usage. All we have to provide is an input image, the output directory to save to (will be created if it does not exist already) as well as the weights file to use.
# We use the **`roi_x_y`** parameter to restrict ourselves to a small part of the image, to speed up the processing - this is usually not required.

# %%
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/BasicDSen20/",
          model_20_file="DSen2/models/s2_032_lr_1e-04.hdf5",
           roi_x_y="1,1,6000,6000")
# Out:
# =========STARTING DSen2==========
# roi_lon_lat:
# roi_x_y:1,1,1500,1500
# run_60:False
# select_UTM:
# deep:False
# output_file_format:GTiff
# copy_original_bands file:True
# ========SETTING UP MODEL=========
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Deep Symbolic Model 20 created and weights loaded from file:DSen2/models/s2_032_lr_1e-04.hdf5
# Deep Symbolic Model 60 created and weights loaded from file:
# ======STARTING PREDICTIONS=======
# Processing data file:Data/Inputs/S2A_MSIL1C_20191008T100031_N0208_R122_T33TWM_20191008T110931.zip
# Predicting using 20m Model
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 196/196 [==============================] - 3s 13ms/step
# (6, 1500, 1500)
# Writing to:Data/Outputs/BasicDSen20/S2A_MSIL1C_20191008T100031_N0208_R122_T33TWM_20191008T110931_supres.tif
# ---------Prediction Done---------
# ---------------------------------
# Processing data file:Data/Inputs/S2A_MSIL1C_20190401T100031_N0207_R122_T33TWM_20190401T105727.zip
# Predicting using 20m Model
# 196/196 [==============================] - 1s 5ms/step
# (6, 1500, 1500)
# Writing to:Data/Outputs/BasicDSen20/S2A_MSIL1C_20190401T100031_N0207_R122_T33TWM_20190401T105727_supres.tif
# ---------Prediction Done---------
# ---------------------------------

# %%
 model_20_file="DSen2/models/s2_032_lr_1e-04.hdf5",
 model_60_file="DSen2/models/s2_030_lr_1e-05.hdf5",
 #my model
 "DSen2/models/s2_032_lr_1e-04.hdf5"

# %% [markdown]
# ##### Superresolution of also the 60m bands
#
# If we also want to superresolve the 60m bands, this is as easy as providing an additional weights file for the 60m model.

# %%
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/BasicDSen60/",
          model_20_file="Data/Training/network_data/slo_model20.hdf5",
          model_60_file="Data/Training/network_data/slo_model60.hdf5",
          roi_x_y="1,1,10980,10980")
# Out:
# =========STARTING DSen2==========
# roi_lon_lat:
# roi_x_y:1,1,10980,10980
# run_60:True
# select_UTM:
# deep:False
# output_file_format:GTiff
# copy_original_bands file:True
# ========SETTING UP MODEL=========
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Deep Symbolic Model 20 created and weights loaded from file:Data/Training/network_data/slo_model20.hdf5
# Deep Symbolic Model 60 created and weights loaded from file: Data/Training/network_data/slo_model.hdf5
# ======STARTING PREDICTIONS=======
# Processing data file:Data/Inputs/S2B_MSIL1C_20190913T100029_N0208_R122_T33TVL_20190913T134222.zip
# Predicting using 60m Model
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 4356/4356 [==============================] - 58s 13ms/step
# (2, 10980, 10980)
# Predicting using 20m Model
# 9801/9801 [==============================] - 52s 5ms/step
# (6, 10980, 10980)
# Writing to:Data/Outputs/BasicDSen60/S2B_MSIL1C_20190913T100029_N0208_R122_T33TVL_20190913T134222_supres.tif
# ---------Prediction Done---------
# ---------------------------------

# %%
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/ena/",
          model_20_file="Data/Training/network_data/slo_model20.hdf5",
          model_60_file="Data/Training/network_data/slo_model.hdf5",
          roi_x_y="1,1,5490,10980")
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/dva/",
          model_20_file="Data/Training/network_data/slo_model20.hdf5",
          model_60_file="Data/Training/network_data/slo_model.hdf5",
          roi_x_y="5490,1,10980,10980")
# Out:
# =========STARTING DSen2==========
# roi_lon_lat:
# roi_x_y:1,1,5490,10980
# run_60:True
# select_UTM:
# deep:False
# output_file_format:GTiff
# copy_original_bands file:True
# ========SETTING UP MODEL=========
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Deep Symbolic Model 20 created and weights loaded from file:Data/Training/network_data/slo_model20.hdf5
# Deep Symbolic Model 60 created and weights loaded from file: Data/Training/network_data/slo_model.hdf5
# ======STARTING PREDICTIONS=======
# Processing data file:Data/Inputs/S2B_MSIL1C_20190913T100029_N0208_R122_T33TVL_20190913T134222.zip
# Predicting using 60m Model
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2178/2178 [==============================] - 32s 15ms/step
# (2, 10980, 5490)
# Predicting using 20m Model
# 4950/4950 [==============================] - 27s 5ms/step
# (6, 10980, 5490)
# Writing to:Data/Outputs/ena/S2B_MSIL1C_20190913T100029_N0208_R122_T33TVL_20190913T134222_supres.tif
# ---------Prediction Done---------
# ---------------------------------
# =========STARTING DSen2==========
# roi_lon_lat:
# roi_x_y:5490,1,10980,10980
# run_60:True
# select_UTM:
# deep:False
# output_file_format:GTiff
# copy_original_bands file:True
# ========SETTING UP MODEL=========
# Deep Symbolic Model 20 created and weights loaded from file:Data/Training/network_data/slo_model20.hdf5
# Deep Symbolic Model 60 created and weights loaded from file: Data/Training/network_data/slo_model.hdf5
# ======STARTING PREDICTIONS=======
# Processing data file:Data/Inputs/S2B_MSIL1C_20190913T100029_N0208_R122_T33TVL_20190913T134222.zip
# Predicting using 60m Model
# 2178/2178 [==============================] - 26s 12ms/step
# (2, 10980, 5490)
# Predicting using 20m Model
# 4950/4950 [==============================] - 26s 5ms/step
# (6, 10980, 5490)
# Writing to:Data/Outputs/dva/S2B_MSIL1C_20190913T100029_N0208_R122_T33TVL_20190913T134222_supres.tif
# ---------Prediction Done---------
# ---------------------------------

# %% [markdown]
# ##### Superresolving using the Very Deep Model for 20m
# To use the deep model, we switch the deep parameter to true, and also have to provide a weights file for the deep model.

# %%
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/BasicVDSen20/",
          model_20_file="DSen2/models/s2_033_lr_1e-04.hdf5",
          deep=True,
          roi_x_y="1,1,300,300")
# Out:
# =========STARTING DSen2==========
# roi_lon_lat:
# roi_x_y:1,1,300,300
# run_60:False
# select_UTM:
# deep:True
# output_file_format:GTiff
# copy_original_bands file:True
# ========SETTING UP MODEL=========
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-32-90419e6c7ac5> in <module>()
#       3           model_20_file="DSen2/models/s2_033_lr_1e-04.hdf5",
#       4           deep=True,
# ----> 5           roi_x_y="1,1,300,300")
#
# /content/gdrive/My Drive/DSen2OP/DSen2/python/DSen2_sl.py in DSen2_sl(input_files, output_dir, model_20_file, model_60_file, roi_lon_lat, roi_x_y, copy_original_bands, select_UTM, deep, output_file_format)
#      50     input_shape = ((4, None, None), (6, None, None))
#      51     model_20=s2model(input_shape, num_layers=num_layers, feature_size=feature_size)
# ---> 52     model_20.load_weights(model_20_file)
#      53     if deep:
#      54         print('Very Deep Symbolic Model 20 created and weights loaded from file:'+model_20_file)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1219         if h5py is None:
#    1220             raise ImportError('`load_weights` requires h5py.')
# -> 1221         with h5py.File(filepath, mode='r') as f:
#    1222             if 'layer_names' not in f.attrs and 'model_weights' in f:
#    1223                 f = f['model_weights']
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'DSen2/models/s2_033_lr_1e-04.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# ##### Superresolving using the Very Deep Model for 60m
#
# And just as before, to use the 60m model we just provide the weights file.

# %%
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/BasicVDSen60/",
          model_20_file="DSen2/models/s2_033_lr_1e-04.hdf5",
          model_60_file="DSen2/models/s2_034_lr_1e-04.hdf5",   
          #model_60_file="Data/Training/network_data/GutesModell.hdf5",  #Use this if we have created it in Part A.
          deep=True,
          roi_x_y="1,1,300,300")
# Out:
# =========STARTING DSen2==========
# roi_lon_lat:
# roi_x_y:1,1,300,300
# run_60:True
# select_UTM:
# deep:True
# output_file_format:GTiff
# copy_original_bands file:True
# ========SETTING UP MODEL=========
# Very Deep Symbolic Model 20 created and weights loaded from file:DSen2/models/s2_033_lr_1e-04.hdf5
# Very Deep Symbolic Model 60 created and weights loaded from file: DSen2/models/s2_034_lr_1e-04.hdf5
# ======STARTING PREDICTIONS=======
# Processing data file:Data/Inputs/S2B_MSIL1C_20190823T103029_N0208_R108_T32UMB_20190823T124349.zip
# Predicting using 60m Model
# 4/4 [==============================] - 3s 667ms/step
# (2, 300, 300)
# Predicting using 20m Model
# 9/9 [==============================] - 2s 273ms/step
# (6, 300, 300)
# Writing to:Data/Outputs/BasicVDSen60/S2B_MSIL1C_20190823T103029_N0208_R108_T32UMB_20190823T124349_supres.tif
# ---------Prediction Done---------
# ---------------------------------
# Processing data file:Data/Inputs/S2B_MSIL1C_20190823T103029_N0208_R108_T32UNA_20190823T124349.zip
# Predicting using 60m Model
# 4/4 [==============================] - 1s 224ms/step
# (2, 300, 300)
# Predicting using 20m Model
# 9/9 [==============================] - 1s 102ms/step
# (6, 300, 300)
# Writing to:Data/Outputs/BasicVDSen60/S2B_MSIL1C_20190823T103029_N0208_R108_T32UNA_20190823T124349_supres.tif
# ---------Prediction Done---------
# ---------------------------------

# %% [markdown]
# ##### Only 20m bands
#
# If we are not interested in the original 10m bands (we already have them, after all) we can use the **`copy_original_bands`** switch to only return the bands we actually superresolved.

# %%
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/OnlyDSen20/",
          model_20_file="DSen2/models/s2_032_lr_1e-04.hdf5",
          roi_x_y="1,1,300,300",copy_original_bands=False)
# Out:
# =========STARTING DSen2==========
# roi_lon_lat:
# roi_x_y:1,1,300,300
# run_60:False
# select_UTM:
# deep:False
# output_file_format:GTiff
# copy_original_bands file:False
# ========SETTING UP MODEL=========
# Deep Symbolic Model 20 created and weights loaded from file:DSen2/models/s2_032_lr_1e-04.hdf5
# Deep Symbolic Model 60 created and weights loaded from file:
# ======STARTING PREDICTIONS=======
# Processing data file:Data/Inputs/S2B_MSIL1C_20190823T103029_N0208_R108_T32UMB_20190823T124349.zip
# Predicting using 20m Model
# 9/9 [==============================] - 2s 172ms/step
# (6, 300, 300)
# Writing to:Data/Outputs/OnlyDSen20/S2B_MSIL1C_20190823T103029_N0208_R108_T32UMB_20190823T124349_supres.tif
# ---------Prediction Done---------
# ---------------------------------
# Processing data file:Data/Inputs/S2B_MSIL1C_20190823T103029_N0208_R108_T32UNA_20190823T124349.zip
# Predicting using 20m Model
# 9/9 [==============================] - 0s 7ms/step
# (6, 300, 300)
# Writing to:Data/Outputs/OnlyDSen20/S2B_MSIL1C_20190823T103029_N0208_R108_T32UNA_20190823T124349_supres.tif
# ---------Prediction Done---------
# ---------------------------------

# %% [markdown]
# ##### Restricting the AOI
# We can pass a string of X1, Y1, X2, X2 coordinates to **`roi_lon_lat`** to restrict the processing to a certain AOI. Of course, this mostly makes sense if the AOI overlaps all our input images, and will fail if one image has zero data within the AOI.
#
# Here, we can see from the prediction time that our AOI contains a lot more data for the first image than the second, increasing the array size and prediction time.

# %%
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/AOI_lon_lat/",
          model_20_file="DSen2/models/s2_032_lr_1e-04.hdf5",
          model_60_file="DSen2/models/s2_030_lr_1e-05.hdf5",
         roi_lon_lat="9,50.525986633828595,9.115343725999678,50.6521965147419")
# Out:
# =========STARTING DSen2==========
# roi_lon_lat:9,50.525986633828595,9.115343725999678,50.6521965147419
# roi_x_y:
# run_60:True
# select_UTM:
# deep:False
# output_file_format:GTiff
# copy_original_bands file:True
# ========SETTING UP MODEL=========
# Deep Symbolic Model 20 created and weights loaded from file:DSen2/models/s2_032_lr_1e-04.hdf5
# Deep Symbolic Model 60 created and weights loaded from file: DSen2/models/s2_030_lr_1e-05.hdf5
# ======STARTING PREDICTIONS=======
# Processing data file:Data/Inputs/S2B_MSIL1C_20190823T103029_N0208_R108_T32UMB_20190823T124349.zip
# Predicting using 60m Model
# 45/45 [==============================] - 3s 74ms/step
# (2, 1404, 816)
# Predicting using 20m Model
# 104/104 [==============================] - 3s 30ms/step
# (6, 1404, 816)
# Writing to:Data/Outputs/AOI_lon_lat/S2B_MSIL1C_20190823T103029_N0208_R108_T32UMB_20190823T124349_supres.tif
# ---------Prediction Done---------
# ---------------------------------
# Processing data file:Data/Inputs/S2B_MSIL1C_20190823T103029_N0208_R108_T32UNA_20190823T124349.zip
# Predicting using 60m Model
# 10/10 [==============================] - 0s 31ms/step
# (2, 288, 816)
# Predicting using 20m Model
# 24/24 [==============================] - 0s 13ms/step
# (6, 288, 816)
# Writing to:Data/Outputs/AOI_lon_lat/S2B_MSIL1C_20190823T103029_N0208_R108_T32UNA_20190823T124349_supres.tif
# ---------Prediction Done---------
# ---------------------------------

# %% [markdown]
# #### Timing the Models
#
# To see how much faster the DSen2 is compared to its deeper counterpart VDSen2, we roughly time the prediction twice - once for a small AOI, once for a medium AOI and once for a large AOI.

# %% [markdown]
# ##### Small AOI

# %%
# %%capture
import time
start_time = time.time()
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/TimingTest/",
          model_20_file="DSen2/models/s2_032_lr_1e-04.hdf5",
          model_60_file="DSen2/models/s2_030_lr_1e-05.hdf5",
          roi_x_y="1,1,300,300")
Deep_Time= time.time() - start_time

start_time = time.time()
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/TimingTest/",
          model_20_file="DSen2/models/s2_033_lr_1e-04.hdf5",
          model_60_file="DSen2/models/s2_034_lr_1e-04.hdf5",   
          deep=True,
          roi_x_y="1,1,300,300")
Very_Deep_Time= time.time() - start_time

# %%
print("DSen2 Time: " + str(Deep_Time)+"\n VDSen2 Time: "+str(Very_Deep_Time))
# Out:
# DSen2 Time: 24.032052278518677
#  VDSen2 Time: 31.71060013771057

# %% [markdown]
# Not a massive difference.

# %% [markdown]
# ##### Medium AOI

# %%
# %%capture
import time
start_time = time.time()
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/TimingTest/",
          model_20_file="DSen2/models/s2_032_lr_1e-04.hdf5",
          model_60_file="DSen2/models/s2_030_lr_1e-05.hdf5",
          roi_x_y="1,1,1000,1000")
Deep_Time= time.time() - start_time

start_time = time.time()
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/TimingTest/",
          model_20_file="DSen2/models/s2_033_lr_1e-04.hdf5",
          model_60_file="DSen2/models/s2_034_lr_1e-04.hdf5",   
          deep=True,
          roi_x_y="1,1,1000,1000")
Very_Deep_Time= time.time() - start_time

# %%
print("DSen2 Time: " + str(Deep_Time)+"\n VDSen2 Time: "+str(Very_Deep_Time))
# Out:
# DSen2 Time: 31.127756595611572
#  VDSen2 Time: 59.742024421691895

# %% [markdown]
# ##### Large AOI

# %%
# %%capture
import time
start_time = time.time()
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/TimingTest/",
          model_20_file="DSen2/models/s2_032_lr_1e-04.hdf5",
          model_60_file="DSen2/models/s2_030_lr_1e-05.hdf5",
          roi_x_y="1,1,4000,4000")
Deep_Time= time.time() - start_time

start_time = time.time()
DSen2_sl(input_files=image_zips,
          output_dir="Data/Outputs/TimingTest/",
          model_20_file="DSen2/models/s2_033_lr_1e-04.hdf5",
          model_60_file="DSen2/models/s2_034_lr_1e-04.hdf5",   
          deep=True,
          roi_x_y="1,1,4000,4000")
Very_Deep_Time= time.time() - start_time

# %%
print("DSen2 Time: " + str(Deep_Time)+"\n VDSen2 Time: "+str(Very_Deep_Time))
# Out:
# DSen2 Time: 246.17463541030884
#  VDSen2 Time: 580.7024714946747

# %% [markdown]
# Now the difference really shows!
